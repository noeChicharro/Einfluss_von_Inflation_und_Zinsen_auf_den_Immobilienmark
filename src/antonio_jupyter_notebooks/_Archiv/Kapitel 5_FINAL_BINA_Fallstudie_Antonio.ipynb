# %% [markdown]
# # 🔮 Kapitel 5: Forecasting & Zeitreihenanalyse
#
# ## 5.1 Zielsetzung und Methodik
# Ziel dieses Kapitels ist es, auf Basis historischer Preisverläufe Prognosen für kommende Quartale zu erstellen. Dazu wird ARIMA verwendet.

# %% [markdown]
# ## 5.2 Stationarität prüfen
# Vor Anwendung eines Zeitreihenmodells muss die Serie stationär sein.

# %% [markdown]
# ## 5.3 ACF/PACF & Modellwahl
# Identifikation geeigneter Modellparameter mithilfe von Autokorrelation und partieller Autokorrelation.

# %% [markdown]
# ## 5.4 Modelltraining & Forecast
# Training eines ARIMA-Modells und Ausgabe der Prognosewerte.

# %% [markdown]
# ## 5.5 Modellbewertung (optional)
# Messung der Vorhersagegenauigkeit mit MAE und RMSE.
