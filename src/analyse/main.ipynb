# %% [markdown]
# # Der Einfluss von Zinsen & Inflation auf den Schweizer Immobilienmarkt (2013–2025)
# R. Bucheli · N. Chicharro · A. Del Roio · D. Hyams · F. Schär
#
# ## Management Summary
#
# Die vorliegende datenbasierte Fallstudie untersucht den Einfluss von Zinsen und Inflation auf den Schweizer Immobilienmarkt im Zeitraum von 2013 bis 2025. Ziel der Analyse ist es, zentrale makroökonomische Zusammenhänge aufzudecken und auf dieser Grundlage konkrete Empfehlungen für die Investitionsstrategie der Publica Pensionskasse abzuleiten. Hintergrund ist ein Jahrzehnt stark steigender Immobilienpreise in Kombination mit einem historisch tiefen Zinsniveau, gefolgt von einer geldpolitischen Kehrtwende der Schweizerischen Nationalbank ab dem Jahr 2022. Die damit einhergehenden Zinserhöhungen führten zu markanten Veränderungen bei Hypothekarzinsen, Finanzierungskosten und Transaktionsvolumen.
#
# Um die Auswirkungen dieser makroökonomischen Veränderungen fundiert zu analysieren, wurden strukturierte Zeitreihendaten aus verschiedenen Quellen ausgewertet, darunter Inserats-Daten von DataHive, Inflationsdaten des Bundesamts für Statistik und Zinsdaten der SNB. Die Analyse orientiert sich am fünfstufigen CPA-Modell («From Data to Decisions») und umfasst deskriptive Auswertungen, Korrelationsanalysen sowie Prognosemodelle auf Basis von SARIMA- und SARIMAX-Verfahren. Neben saisonalen Mustern wurden insbesondere externe Einflussfaktoren wie der Hypothekarzinssatz und der Wohnimmobilienpreisindex (IMPI) berücksichtigt.
#
# Die Resultate zeigen, dass die Entwicklung der Immobilienpreise stark durch makroökonomische Rahmenbedingungen geprägt war. Die SARIMAX-Modelle verdeutlichen, dass der IMPI als exogene Variable deutlich robustere und realitätsnähere Prognosen ermöglicht als die kurzfristigeren Zinssätze. Dies spiegelt sich insbesondere in tieferen Prognosefehlern (MAE und RMSE) und einem stabileren Modellverhalten wider. Gleichzeitig weisen Regionen mit guter Erschliessung und mittlerer Wohnungsgrösse (3.5–4.5 Zimmer) ein günstiges Rendite-Risiko-Profil auf.
#
# Für die Publica ergeben sich daraus konkrete Empfehlungen: Ein Fokus auf langfristige Festhypotheken, gut erschlossene ländliche Regionen und das Monitoring der Preisentwicklung mittels robust erklärender exogener Faktoren wie dem IMPI. Darüber hinaus empfiehlt die Projektgruppe, zukünftige Entscheidungen datenbasiert zu unterstützen, etwa durch den Aufbau eines Visual Analytics Dashboards zur laufenden Marktbeobachtung.
#
# Die im Rahmen dieser Fallstudie gewonnenen Erkenntnisse sollen einen praxisnahen Beitrag zur strategischen Steuerung von Investitionen im Schweizer Immobilienmarkt leisten. Aufbauend auf den Resultaten wird im nächsten Kapitel der thematische Kontext im Detail erläutert.
#
#
# ## 1. Einleitung & Kontext
#
# *(CPA Step 1: Defining objectives and information needs)*
#
# Der Schweizer Immobilienmarkt hat sich in den letzten zehn Jahren durch kontinuierlich steigende Preise, anhaltend tiefe Zinsen und ein stabiles wirtschaftliches Umfeld ausgezeichnet. Ab 2022 wurde dieses Gleichgeweicht jedoch spürbar gestört. Global steigende Inflationsraten, Lieferengpässe sowie die geldpolitische Kehrtwende der Schweizerischen Nationalbank (SNB) wirkten sich besonders in den Jahren 2022-2024 deutlich auf Hypothekarzinsen, Transaktionspreise und das Transaktionsvolumen aus. Die SNB reagierte mit Zinserhöhungen, was unmittelbare Auswirkungen auf Hypothekarzinsen und die Finanzierungskosten von Wohneigentum hatte (UBS (Schweiz) AG, 2025). Angesichts eines historisch niedrigen Zinsumfelds in den 2010er-Jahren und einer seit 2022 stark angestiegenen Teuerung stellt sich zunehmend die Frage, in welchem Ausmass Zins- und Inflationsentwicklungen den Wohnimmobilienmarkt beeinflussen und wie tragfähig das gegenwärtige Preisniveau tatsächlich ist. Nicht nur in den städtischen, sondern auch in peripheren Regionen lassen sich seither differenzierte Preisentwicklungen beobachten. Dies ist ein Indiz für eine zunehmende Heterogenität im Markt (UBS (Schweiz) AG, 2024).
#
# Vor dieser Herausforderung steht auch die Publica Pensionskasse. Als eine der grössten Vorsorgeeinrichtungen der Schweiz, muss sie für ihre Versicherten langfristige und stabile Erträge erzielen. In Anbetracht des volatilen Zinsumfelds und der Unsicherheiten im Immobilienmarkt stellt sich für Publica die strategische Frage, welche Kantone und Immobilientypen in Zukunft das beste Rendite-Risiko-Verhältnis bieten.
#
# Mit dieser datenbasierten Case Study möchte die Immobilienabteilung der Publica untersuchen, wie sich die Entwicklung von Zinsen und Inflation zwischen 2013 und 2025 auf den Schweizer Wohnimmobilienmarkt ausgewirkt hat. Die Wechselwirkungen zwischen diesen makroökonomischen Faktoren und der Preisentwicklung werden systematisch analysiert. Das Ziel ist es, der Geschäftsleitung der Publica auf Basis dieser Analysen eine konkrete Entscheidungsgrundlage für zukünftige Investitionen im Immobiliensektor bereitzustellen, die im Einklang mit der Immobilienstrategie der Pensionskasse steht.
#
# Die Case Study fokussiert sich auf die Veränderungen in den Preisniveaus, der Leistbarkeit von Wohneigentum sowie dem Investitionsverhalten. Für die Analyse wurden valide Datenquellen vom Unternehmen DataHive, der Schweizerischen Nationalbank (SNB) und dem Bundesamt für Statistik ausgewertet. Auf Basis der zugrunde liegenden Daten werden zentrale Muster identifiziert, die aufzeigen, wie stark der Einfluss von externen makroökonomischen Faktoren auf den Wohnimmobilienmarkt tatsächlich ist. Zusätzlich wird erläutert in welchen Marktsegmenten eine besonders starke Ausprägung auftritt.
#
# Letztendlich möchte die Projektgruppe mit dieser Arbeit einen Beitrag zur datenbasierten Entscheidungsfindung im Immobiliensektor leisten. Die Analysen und Datenauswertungen sollen aufzeigen, wie Investoren, Kreditgeber und auch politische Akteure in Zukunft nachhaltige Entscheidungen bezüglich Investitionen, Finanzierungen oder Zinsanpassungen im Immobiliensektor tätigen können. Die Erkenntnisse stützen sich auf systematische Analysen von Zeitreihen zu Hypothekarzinssätzen, Inflationsraten und dem Wohnimmobilienpreisindex. Ergänzt werden die Analysen durch aktuelle Marktperspektiven, wie sie in Studien von der UBS (Schweiz) AG (UBS (Schweiz) AG, 2024, 2025) oder im globalen Ausblick von UBS Asset Management (UBS Asset Management, 2025) beschrieben werden.
#
# Die Studie stützt sich auf der fünfstufigen CPA-Methode nach Marr (Marr, 2020). Die untenstehende Grafik zeigt eine Übersicht der fünf Schritte, welche nachfolgend detailliert erläutert werden.
#
# ![image.png](attachment:image.png)
#
# Abbildung 1: Fünf Schritte zur datenbasierten Entscheidungsfindung (eigene Darstellung)
#
# **Schritt 1 - Ziele und Informationsbedarf definieren**
#
# Im ersten Schritt wurden bereits im vorhergehenden Abschnitt die Zielsetzung sowie die benötigten Informationen zur Beantwortung der zentralen Forschungsfrage definiert. In den nachfolgenden Schritten werden die für die vorliegende Fragestellungen relevanten Daten gesammelt, analysiert und präsentiert.
#
# **Schritt 2 - Daten sammeln**
#
# Im zweiten Schritt werden relevante Rohdaten gesammelt und bereinigt. Der Fokus soll dabei auf genügend relevante und aussagekräftige
# Daten gelegt werden. Die Menge an Daten ist deshalb von grosser Bedeutung, weil je mehr Daten gesammelt werden können, desto genauere Aussagen können in Bezug auf die Auswirkung von Zinsen und Inflation auf den Wohnimmobilienmarkt getroffen werden.
#
# **Schritt 3 - Daten analysieren**
#
# Sobald alle relevanten Daten zusammengetragen und bereinigt wurden, geht es im dritten Schritt darum, die Daten zu analysieren, Korrelationen zu erstellen und entsprechende Erkenntnisse abzuleiten. Das Ziel ist es die passenden Analysetechniken rauszufiltern mit den richtigen Methoden möglichst präzise und nützliche Analysen zu erstellen.
#
# **Schritt 4 - Daten präsentieren**
#
# In diesem Schritt werden die Ergebnisse aus Schritt 3 auf eine geeignete Art und Weise präsentiert. Die Projektgruppe erstellt hierfür ein entsprechendes Jupyter Notebook, welches in eine VS Code Umgebung eingebettet ist.
#
# #### Daten Imports für weitere Verarbeitung

# %%
import sys
import os

# Parent directory für das Projekt hinzufügen
project_root = os.path.abspath("..")  
if project_root not in sys.path:
    sys.path.append(project_root)

# Imports aller verwendeten Module
# numpy
import numpy as np
# pandas
import pandas as pd
# matplotlib
import matplotlib.pyplot as matplot
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.cm as cm
import matplotlib.colors as mcolors
# seaborn
import seaborn as sns
# sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
# statsmodels
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
# itertools
import itertools
# squarify
import squarify 

# Vorbereitete Daten aus Datenbank 
import dataService as dataService
import dataHiveService as dhService

import importlib
importlib.reload(dataService)
# Out:
# Q1: 555,000 CHF
# Q3: 1,175,000 CHF
# IQR: 620,000 CHF
# Obere Ausreissergrenze: 2,105,000 CHF
# <module 'dataService' from '/Users/nch/Documents/master/BINA/python/Einfluss_von_Inflation_und_Zinsen_auf_den_Immobilienmark/src/vergleiche/dataService.py'>

# %% [markdown]
# **Schritt 5 - datenbasierte Entscheidungen treffen**
#
# Im letzten Schritt werden basierend auf den präsentierten Ergebnissen aus den Analysen mögliche Handlungsempfehlungen abgeleitet. Die identifizierten Zusammenhänge zwischen Zinsniveau, Inflation und Immobilienpreisen sollen als Grundlage für fundierte Investitionsentscheidungen dienen. Zusätzlich würde sich die Möglichkeit zur Entwicklung eines datenbasierten Dashboards zur laufenden Marktbeobachtung bieten. Dies wird im Rahmen der vorliegenden Case Study jedoch nicht weiterverfolgt.
#
# ## 2. Datenverständnis & Aufbereitung
#
# *(CPA Step 2: Collecting data)*
#
# ### 2.1 Überblick über alle Datensätze
#
# Für die Untersuchung des Einflusses von Zinsen und Inflation auf den Schweizer Immobilienmarkt im Zeitraum **2013–2024** wurden zahlreiche Datensätze aus offiziellen Quellen wie dem **Bundesamt für Statistik (BFS)**, der **Schweizerischen Nationalbank (SNB)** sowie aus einer privaten Quelle (**DataHive**) herangezogen.
#
# Die Datensätze decken verschiedene Themenbereiche ab – darunter Immobilienpreise, Hypothekarzinsen und Konsumentenpreise. Die folgende Tabelle gibt einen strukturierten Überblick über die Datenquellen, Zeiträume sowie zentrale Merkmale der verwendeten Datengrundlagen:
#
# | **Datensatz** | **Zeitraum** | **Quelle** | **Zentrale Merkmale** |
# |---------------|--------------|------------|------------------------|
# | Kaufinserate Schweiz                        | 2018–2025    | DataHive (inkl. NDA)     | Quadratmeterpreis, Anzahl Zimmer, Kanton, Grundstückfläche, Preis, Datum              |
# | Landesindex der Konsumentenpreise (LIK)     | 1914–2025    | BFS                      | Index der Konsumentenpreise                                                           |
# | Hypozinssätze (SNB_Hypo_Zinssätze)          | 2009–2024    | SNB                      | Festhypotheken, variable Hypotheken (5–7 Jahre)                                       |
# | Wohnimmobilienpreisindex                    | 2017–2024    | BFS                      | Eigentumswohnungen, Einfamilienhäuser, Gemeindetypen                                  |

# %% [markdown]
# ## 2.2 DataHive Daten
# Die Daten von DataHive enthalten Informationen zu Immobilieninseraten bekannter Webseiten wie Homegate.ch oder Immoscout.ch. Die uns zur Verfügung gestellten Daten beinhalten alle Immobilieninserate während dem Zeitraum vom 01. Januar 2018 und dem 13. März 2025.
# Die DataHive-Daten ermöglichen es uns, wichtige Kennzahlen wie den Quadratmeterpreis pro Kanton, Durchschnittswerte sowie die Zimmerverteilung zu untersuchen. Die Daten wurden aus einer CSV-Datei in unsere SQL-Datenbank importiert und mithilfe von Python (Pandas, Matplotlib, Seaborn, Squarify) visualisiert.
#
# ### 2.2.1 Datenimport und Tabellenstruktur
# Die Daten wurden zunächst aus der Datei dataHive.csv geladen und über SQLAlchemy in unsere MySQL-Datenbank übertragen. Die Tabelle dataHive enthält Informationen zu Immobilienangeboten wie Preise, Flächenanaben, Lageparameter und Gebäudemerkmale.
#
# *Wichtige Felder der Tabelle:*
#
# * Price_per_sqr_meter: Preis pro Quadratmeter
# * Room_count: Anzahl Zimmer
# * Canton: Kanton (Standort der Immobilie)
# * Area_property: Grundstücksfläche
# * Purchase_price: Kaufpreis
# * Activated: Datum der Inserat-Aufschaltung
#
# *Ausgeschlossene Felder:*
#
# Für unsere Analyse wurde nicht alle verfügbaren Felder aus der DataHive-Datenbank berücksichtigt. So enthält die Datenbank beispielsweise Informationen zur Dauer der Inseratschaltung. Dazu gehören Zeitangaben wie:
# * Inactivated: Datum der Deaktivierung
# * Update_time: Datum der Aktualisierung
# * Delete: Datum der Löschung
#
# Auch das Feld on_market_in_days, das angibt, wie viele Tage ein Inserat online war, wurde nicht verwendet.
# Darüber hinaus existieren Bewertungsdaten zu Qualitätsmerkmalen, etwa:
#
# * Ax_rating_connectivity: Erreichbarkeit
# * Ax_rating_public_transportation: Anbindung zum öffentlichen Verkehr
#
# Obwohl diese Daten interessante Analysemöglichkeiten bieten, sind sie für den Fokus unserer Arbeit - nämlich die Analyse des Einflusses von Inflation und Zinsen auf die Immobilienpreisentwicklung - nicht von Relevanz.
# Daher wurden diese Felder in unserer Untersuchung nicht weiter berücksichtigt.

# %% [markdown]
# ## 3. Datenanalyse
#
# *(CPA Step 3: Analyzing data)*
#
# ### 3.1 Preis pro Quadratmeter nach Kanton
# Mithilfe eines Boxplots wurde der Verteilungspreis pro Quadratmeter nach Kantonen analysiert. Die Darstellung zeigt nicht nur den Medianpreis je Kanton, sondern auch die Spannweite und potenzielle Ausreisser.

# %%
df_clean = dataService.dfDataHive[['price_per_sqr_meter', 'canton']].dropna()

sorted_cantons = (
    df_clean.groupby('canton')['price_per_sqr_meter']
    .median()
    .sort_values()
    .index
)

# Set up the plot
plt.figure(figsize=(14, 6))
sns.boxplot(data=df_clean, x='canton', y='price_per_sqr_meter', order=sorted_cantons, color='dodgerblue')

# Make it readable
plt.xticks(rotation=45)
plt.title('Preisspanne pro Quadratmeter nach Kanton')
plt.xlabel('Kanton')
plt.ylabel('Preis pro Quadratmeter [CHF]')
plt.ylim(100, df_clean['price_per_sqr_meter'].max() * 1.05)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Diese Visualisierung ermöglicht einen schnellen Überblick, in welchen Kantonen Immobilien besonders teuer oder günstig sind, basierend auf dem Preis pro Quadratmeter. Kantone mit breiter Verteilung könnten auf grosse Unterschiede innerhalb des Marktes hinweisen.
#
# ### 3.2 Durchschnittlicher Quadratmeterpreis pro Kanton
# Für eine übersichtliche Darstellung der mittleren Preise wurde ein Balkendiagramm erstellt, das die durchschnittlichen Quadratmeterpreise je Kanton zeigt.

# %%
avg_price_per_canton = dataService.dfDataHive.groupby('canton')['price_per_sqr_meter'].mean().sort_values()

plt.figure(figsize=(14, 6))
avg_price_per_canton.plot(kind='bar', color='dodgerblue')

plt.xlabel('Kanton')
plt.ylabel('Durschnittlicher Quadratmeterpreis [CHF]')
plt.title('Durchschnittlicher Quadratmeterpreis nach Kanton')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Diese Darstellung ist hilfreich, um Preisniveaus direkt zu vergleichen. Hochpreisige Regionen wie Zug oder Genf heben sich hier besonders deutlich ab.
#
# ### 3.3 Durchschnittspreise & Angebotsanzahl
# Zur Kombination von Preisniveau und Angebotsdichte wurde eine Treemap erstellt. Die Grösse eines Rechtecks zeigt die Anzahl an Einträgen, während die Farbe das durchschnittliche Preisniveau je Kanton widerspiegelt.

# %%
df_treemap = dataService.dfDataHive[['canton', 'price_per_sqr_meter']].dropna()

# Aggregate: mean price and count per canton
agg_data = df_treemap.groupby('canton').agg(
    avg_price=('price_per_sqr_meter', 'mean'),
    count=('price_per_sqr_meter', 'count')
).reset_index()

# Size by number of listings
sizes = agg_data['count']
labels = [f"{c}\n{p:,.0f} CHF/m²" for c, p in zip(agg_data['canton'], agg_data['avg_price'])]

# Normalize color values (from 0 to 1)
norm = mcolors.Normalize(vmin=agg_data['avg_price'].min(), vmax=agg_data['avg_price'].max())

# Use 'Blues' colormap for skyblue to deep blue
cmap = cm.get_cmap('Blues')
colors = [cmap(norm(value)) for value in agg_data['avg_price']]

# Create treemap
plt.figure(figsize=(14, 8))
squarify.plot(
    sizes=sizes,
    label=labels,
    color=colors,
    alpha=0.9
)
plt.axis('off')
plt.title('Durchschnittlicher Quadratmeter Preis nach Kanton', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/pf/7t1wjv_n0fl3csqg8486wbbh0000gn/T/ipykernel_20888/2172664273.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Blues')

# %% [markdown]
# Diese Form der Visualisierung hilft, sowohl die Marktgrösse als auch Preisintensität auf einen Blick zu erfassen. Beispielsweise deuten grössere Rechtecke mit dunklerer Farbe auf viele Angebote mit hohen Preisen hin.
#
# ### 3.4 Zimmerverteilung
# In einer weiteren Analyse wurde die Verteilung zu der Anzahl Zimmer in einem Tortendiagramm dargestellt. Dies gibt Aufschluss über die typische Grösse der angebotenen Immobilien, basierend auf der Anzahl Zimmer.

# %%
filtered_data = dataService.dfDataHiveOther[dataService.dfDataHiveOther['room_count'] <= 10]
room_counts = filtered_data['room_count'].value_counts().sort_index()
room_percentages = (room_counts / room_counts.sum()) * 100

# Filter 0% aus
non_zero_mask = room_percentages > 1
room_counts = room_counts[non_zero_mask]
room_percentages = room_percentages[non_zero_mask]

cmap = cm.get_cmap('Blues')
colors = [cmap(i / len(room_counts)) for i in range(len(room_counts))]

# Plot pie chart
fig, ax = plt.subplots(figsize=(10, 10))
ax.pie(
    room_counts,
    colors=colors,
    labels=room_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    labeldistance=1.05,
    pctdistance=0.85

)
ax.set_title('Zimmeranzahlverteilung')
ax.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/pf/7t1wjv_n0fl3csqg8486wbbh0000gn/T/ipykernel_20888/1319228923.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Blues')

# %% [markdown]
# ### 3.5 Landesindex der Konsumentenpreise (LIK) 1914-2024
#
# Der Landesindex für Konsumentenpreise (LIK) ist einer der am häufigsten angewandten Wirtschaftsindikatoren und dient u.a. zur Beobachtung der Preisentwicklung und gilt als Hilfsmittel zur Bereinigung statistischer Daten sowie als Wirtschaftsindikator für Ländervergleiche (Landesindex der Konsumentenpreise, 2025).
# Der LIK misst die Teuerung (Inflation) der Konsumgüter in der Schweiz. Er zeigt auf, um wie viel die Konsumgüter gegenüber anderen Zeitpunkten teurer geworden sind und ist somit ein Indikator für die durchschnittliche Preisentwicklung von repräsentativ ausgewählten Waren und Dienstleistungen des privaten Konsums. Dabei werden die Waren und Dienstleistungen auf Basis einer Erhebung des Haushaltsbudgets nach international üblichen Klassifizierungen in einen Warenkorb aufgeteilt.
#
# ![KostenCH.png](assets/KostenCH.png)
# (Quelle: BFS, 2021)
#
# Die Preise dieser ausgewählten Artikel werden über die umsatzstärksten Verkaufsstellen von elf Preiserhebungsregionen der Schweiz erhoben und zusammengeführt.
# Die für diese Arbeit gewählten Daten umfassen den gesamten Zeitraum des LIK seit der Einführung um 1914, als der Grundwert für den Index auf 100 Punkte festgelegt wurde. Die vorliegenden Daten enthalten einen jährlichen Wert.

# %%
## PREDICTION - polynomial regression
coeffs = np.polyfit(dataService.dfLikBig['jahr'], dataService.dfLikBig['lik'], deg=2)
poly_model = np.poly1d(coeffs)

# Predict
future_years = np.arange(2024, 2064)
predicted_lip = poly_model(future_years)

# Plot
matplot.figure(figsize=(10, 5))
matplot.plot(dataService.dfLikBig['jahr'], dataService.dfLikBig['lik'], label='LIK (historisch)', marker='', color='dodgerblue')
matplot.plot(future_years, predicted_lip, label='LIK (Vorhersage)', marker='x', linestyle='--', color='forestgreen')
matplot.plot(np.concatenate((dataService.dfLikBig['jahr'], future_years)), poly_model(np.concatenate((dataService.dfLikBig['jahr'], future_years))), 
         label='polynomialer Trend', linestyle=':', color='turquoise')

matplot.title('LIK Vorhersage mit polynomialer Regression')
matplot.xlabel('Jahr')
matplot.ylabel('Inflationsrate')
matplot.legend()
matplot.grid(True)
matplot.show()

# %% [markdown]
# ### 3.6 Zinsdaten Hypotheken 2009-2025
# Die Schweizerische Nationalbank publiziert die monatlichen Zinssätze von neuen Kreditabschlüssen von Dezember 2009 bis Januar 2025. Die erfassten Zinssätze umfassen die Sätze von neuen Hypotheken am Monatsende, aufgrund der veröffentlichten oder auf Anfrage kommunizierten Daten. Die Anzahl der Abschlüsse beinhaltet Geschäfte, die auf Schweizer Franken lauten oder von einer Geschäftsstelle in der Schweiz abgeschlossen wurden. Es handelt sich um eine Teilerhebung.
# Die verfügbaren Daten sind sehr umfangreich und wurden teilweise statistisch aufbereitet. So wird grundsätzlich zwischen festverzinslichen und variabelverzinslichen Hypothekenarten unterschieden, wobei jeweils unterschiedliche Laufzeiten zur Verfügung stehen. Die statistische Aufbereitung besteht aus den Angaben zum Mittelwert, 25%-Quantil, Median, 75%-Quantil.
#
# Aufgrund der hohen Anzahl von 225 abgeschlossenen Hypotheken liegen dieser Arbeit die Mittelwerte der festverzinsliche Hypothek mit einer Laufzeit von 7-10 Jahren zugrunde.
#
# ### 3.7 Schweizerischer Wohnimmobilienpreisindex (IMPI) 2017-2024
# Der Schweizerische Wohnimmobilienpreisindex (IMPI) misst vierteljährlich die Entwicklung der Marktpreise für Wohneigentum. Dabei wird die Schweiz in fünf unterschiedliche Gemeindetypen unterteilt:
# -	Städtische Gemeinde einer grossen Agglomeration
# -	Städtische Gemeinde einer mittelgrossen Agglomeration
# -	Städtische Gemeinde einer kleinen oder ausserhalb einer Agglomeration
# -	Intermediäre Gemeinde
# -	Ländliche Gemeinde
#
# Der IMPI weist neben einem Totalwert separate Werte Einfamilienhäuser und Eigentumswohnungen aus. Dieser Arbeit liegt der Totalwert des Wohneigentums zugrunde.
# Die Entwicklung der Marktpreise für Wohneigentum entwickelt sich gemäss IMPI über alle Gemeindetypen hinweg gleichförmig.

# %%
plt.figure(figsize=(12, 6))
colors = ['dodgerblue', 'forestgreen', 'turquoise', 'teal', 'darkviolet']

for col, color in zip(['Typ 1', 'Typ 2', 'Typ 3', 'Typ 4', 'Typ 5'], colors):

    plt.plot(dataService.dfGemeindetypen['jahr'], dataService.dfGemeindetypen[col], marker='o', label=col, color=color) 

plt.title('Entwicklung des Wohneigentums über die Jahre')
plt.xlabel('Jahr')
plt.ylabel('Durchschnittlicher Wert')
plt.legend(title='Gemeindetyp')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Dennoch lässt sich klar der Trend erkennen, dass die Preisentwicklung der Immobilien des Gemeindetyps 3 «Städtische Gemeinde einer kleinen oder ausserhalb einer Agglomeration» in den letzten drei Jahren überdurchschnittlich stark angestiegen sind. Die Attraktivität für eine Investition in Immobilien von Gemeinden von grossen Agglomerationen ist während der letzten Jahre somit massiv gestiegen.

# %%
plt.figure(figsize=(12, 6))

highlight = 'Typ 3' 

for col in ['Typ 1', 'Typ 2', 'Typ 3', 'Typ 4', 'Typ 5']:

    if col == highlight:
        plt.plot(dataService.dfGemeindetypen['jahr'], dataService.dfGemeindetypen[col], label=col, linewidth=3, color='turquoise')
    else:
        plt.plot(dataService.dfGemeindetypen['jahr'], dataService.dfGemeindetypen[col], label=col, linewidth=1.5, linestyle='--', color='gray')

plt.title('Entwicklung des Wohneigentums über die Jahre')
plt.xlabel('Jahr')
plt.ylabel('Durchschnittlicher Wert')
plt.legend(title='Gemeindetyp')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Korrelationen & Datenanalyse
# *(CPA Step 3: Analyzing data)*
#
# In diesem Kapitel wird auf Basis der bereinigten und vorbereiteten Datengrundlage eine detaillierte Analyse des Schweizer Immobilienmarkts durchgeführt. Ziel ist es, zentrale Entwicklungen im Kaufpreisniveau zwischen 2018 und 2025 zu identifizieren und diese im Zusammenhang mit externen Einflussfaktoren wie Hypothekarzinsen und Inflation zu interpretieren.
#
# Dazu werden in einem ersten Schritt deskriptive Auswertungen und Visualisierungen auf monatlicher, quartalsweiser und jährlicher Ebene vorgenommen. Anschliessend werden Korrelationen zwischen internen und externen Variablen analysiert, um potenzielle Abhängigkeiten und Wirkzusammenhänge zu erkennen. Diese bilden die Grundlage für die anschliessende Zeitreihenanalyse in Kapitel 5.
#
# Der Fokus liegt dabei insbesondere auf der Spalte `purchase_price` des DataHive-Datensatzes, die zuvor bereinigt und geprüft wurde. Zur Ergänzung werden externe Datenquellen der Schweizerischen Nationalbank (Festverzinsliche Hypotheken), des Bundesamts für Statistik (Inflationsrate: LIK) sowie des BFS-Wohnimmobilienpreisindex (IMPI) eingebunden.
#
# ## 4.1 Zielsetzung und Methodik
#
# Ziel dieses Abschnitts ist es, zentrale Zusammenhänge zwischen dem Kaufpreisniveau von Wohnimmobilien und externen Einflussgrössen wie Zinssätzen und Inflation im Zeitraum 2018–2025 datenbasiert zu untersuchen. Dafür werden sowohl deskriptive Verfahren als auch korrelationsbasierte Ansätze eingesetzt.
#
# Die Datenanalyse erfolgt anhand des bereinigten Hauptdatensatzes `dfDataHiveCleaned`, der auf dem DataHive-Datensatz basiert und zuvor von Ausreissern bereinigt sowie auf Konsistenz geprüft wurde. Ergänzend werden Datenreihen zu Hypothekarzinsen, zur Inflationsentwicklung sowie zum offiziellen Wohnimmobilienpreisindex (IMPI) aus öffentlich zugänglichen Quellen (SNB, BFS) eingebunden.
#
# Als methodisches Vorgehen werden folgende Schritte umgesetzt:
#
# - Aggregation der Kaufpreise auf Monats-, Quartals- und Jahresebene
# - Zusammenführung mit externen Zeitreihen (Zinsen, Inflation, IMPI)
# - Deskriptive Visualisierungen (z. B. Trendlinien, Scatterplots, Boxplots)
# - Analyse der Zusammenhänge mittels Pearson-Korrelationskoeffizienten
# - Interpretation der Ergebnisse im Kontext makroökonomischer Entwicklungen
#
# Die Erkenntnisse aus dieser Phase liefern eine erste datenbasierte Grundlage zur Beurteilung, ob (und in welchem Ausmass) Zinsniveau, Inflation oder der offizielle Wohnimmobilienpreisindex als Treiber der Preisentwicklung identifiziert werden können.
#
# ## 4.2 Datenzusammenführung
#
# Für die anschliessende Korrelationsanalyse werden die bereinigten Kaufpreisdaten aus `dfDataHiveCleaned` mit externen Einflussgrössen zusammengeführt. Dabei wird jede externe Variable auf der zeitlichen Granularität berücksichtigt, in der sie vorliegt. Ziel ist es, den maximal verfügbaren Zeitraum jeder Datenquelle vollständig auszuschöpfen und möglichst präzise Zusammenhänge zu identifizieren.
#
# Das Vorgehen umfasst deshalb drei getrennte Aggregations- und Merge-Schritte:
#
# - **Kaufpreise vs. Hypothekarzinsen**
#   → Zusammenführung auf **monatlicher Basis** mit den SNB-Zinsdaten (`df_zins`)
#
# - **Kaufpreise vs. Inflationsraten (LIK)**
#   → Zusammenführung auf **jährlicher Basis** mit den BFS-Inflationsdaten (`df_inflation`)
#
# - **Kaufpreise vs. Wohnimmobilienpreisindex (IMPI)**
#   → Zusammenführung auf **quartalsweiser Basis** mit dem BFS-Wohnindex (`df_wohn`)
#
# Für jeden dieser Schritte wird der Median der Kaufpreise entsprechend der jeweiligen zeitlichen Auflösung aggregiert und anschliessend mit dem externen Datensatz verknüpft. Die so entstandenen Teil-Datensätze dienen jeweils als Grundlage für die darauf folgende Korrelations- und Trendanalyse.

# %% [markdown]
# ### 4.2.1 Kaufpreis vs. Zinsen (monatlich)
#
# Im ersten Schritt wird der Median der Kaufpreise pro Monat berechnet und mit den monatlichen Hypothekarzinssätzen der Schweizerischen Nationalbank (SNB) zusammengeführt. Dadurch lässt sich untersuchen, ob und wie stark ein Zusammenhang zwischen dem Zinsniveau (fest und variabel) und der Entwicklung der Immobilienpreise auf monatlicher Basis besteht.
#
# Die Kaufpreise werden anhand des Aktivierungsdatums (`activated`) monatlich aggregiert. Der Merge erfolgt über Jahr und Monat mit den Zinsdaten (`df_zins`), die sowohl feste als auch variable Hypothekarzinsen enthalten.

# %%
# Stil setzen
sns.set(style="whitegrid")

# Scatterplot: Festhypozins (Median) vs. Kaufpreis
plt.figure(figsize=(10, 6))
sns.regplot(x='festhypo_median', y='median_kaufpreis', data=dhService.df_merge_zins, line_kws={'color': 'dodgerblue'})
plt.title('Höhere Hypothekarzinsen gehen mit steigenden Kaufpreisen einher (Monatsbasis, 2018–2024)')
plt.xlabel('Festhypothekarzins Median [%]')
plt.ylabel('Kaufpreis Median [CHF]')

# Tausendertrennzeichen im Schweizer Format auf Y-Achse
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:,.0f}".replace(",", "'")))

plt.tight_layout()
plt.show()

# %%
# Scatterplot: Variabelhypozins (Median) vs. Kaufpreis
plt.figure(figsize=(10, 6))
sns.regplot(x='variabelhypo_median', y='median_kaufpreis', data=dhService.df_merge_zins, line_kws={'color': 'dodgerblue'})
plt.title('Höhere variable Hypothekarzinsen gehen mit steigenden Kaufpreisen einher (Monatsbasis, 2018–2024)')
plt.xlabel('Variabler Hypothekarzins Median [%]')
plt.ylabel('Kaufpreis Median [CHF]')

# Tausendertrennzeichen im Schweizer Format auf Y-Achse
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:,.0f}".replace(",", "'")))

plt.tight_layout()
plt.show()

# %%
# Nur relevante Spalten extrahieren
corr_data = dhService.df_merge_zins[['median_kaufpreis', 'festhypo_median', 'variabelhypo_median']]

# Beschriftung der Spalten anpassen 
corr_data.columns = ['Kaufpreis Median', 'Fester Hypozins Median', 'Variabler Hypozins Median']

# Korrelationsmatrix berechnen
corr_matrix = corr_data.corr(method='pearson')

# Heatmap anzeigen
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='Blues', fmt=".2f")
plt.title("Korrelation zwischen Zinsen und Kaufpreisen (Pearson-Koeffizienten)", pad=20)
plt.xticks(rotation=45)  # X-Achsen-Beschriftung schräg stellen
plt.tight_layout()
plt.show()

# %%
# Formatierte Monatslabels erzeugen
dhService.df_merge_zins.rename(columns={'jahr': 'year', 'monat': 'month'}, inplace=True)
dhService.df_merge_zins['zeit'] = pd.to_datetime(dhService.df_merge_zins[['year', 'month']].assign(day=1))
df_merge_zins = dhService.df_merge_zins.sort_values('zeit')  # Sortieren nach Zeit

labels = df_merge_zins['zeit'].dt.strftime('%Y-%m')

# Plot erstellen
fig, ax1 = plt.subplots(figsize=(16, 6))

# Kaufpreis (linke y-Achse)
ax1.plot(df_merge_zins['zeit'], df_merge_zins['median_kaufpreis'],
         color='dodgerblue', marker='o', label='Median Kaufpreis')
ax1.set_ylabel('Kaufpreis [CHF]', color='dodgerblue')
ax1.tick_params(axis='y', labelcolor='dodgerblue')

# Hypozins (rechte y-Achse)
ax2 = ax1.twinx()
ax2.plot(df_merge_zins['zeit'], df_merge_zins['festhypo_median'],
         color='turquoise', marker='s', linestyle='--', label='Festhypothekarzins')
ax2.set_ylabel('Hypothekarzins [%]', color='turquoise')
ax2.tick_params(axis='y', labelcolor='turquoise')

# Monatliche Labels setzen
ax1.set_xticks(df_merge_zins['zeit'])
ax1.set_xticklabels(labels, rotation=45, fontsize=8)

# Gitternetzlinien aktivieren
ax1.grid(True)

# Titel und Layout
plt.title('Vergleich: Median-Kaufpreis und Hypothekarzins pro Monat')
ax1.set_xlabel('Monat')

# Legende für beide Achsen anzeigen
fig.legend(loc='upper left', bbox_to_anchor=(0.11, 0.9))

plt.tight_layout()
plt.show()

dhService.df_merge_zins.rename(columns={'year': 'jahr', 'month': 'monat'}, inplace=True)

# %% [markdown]
# ### Interpretation der Ergebnisse zum Kapitel 4.2.1
#
# Die deskriptive Analyse auf monatlicher Ebene zeigt einen deutlich positiven Zusammenhang zwischen dem Median der Immobilienkaufpreise und den Hypothekarzinssätzen im Zeitraum von Januar 2018 bis Dezember 2024. Dabei wurden sowohl feste als auch variable Zinssätze berücksichtigt.
#
# Die Scatterplots mit linearer Regressionslinie verdeutlichen, dass ein Anstieg der Zinsen tendenziell mit einem Anstieg der Median-Kaufpreise einhergeht. Diese Beobachtung wirkt auf den ersten Blick kontraintuitiv, da höhere Finanzierungskosten aus ökonomischer Sicht typischerweise eine dämpfende Wirkung auf die Nachfrage und damit auf die Immobilienpreise haben sollten.
#
# Die berechnete Pearson-Korrelationsmatrix stützt diese Beobachtung: Zwischen dem festen Hypothekarzins (Median) und dem Median-Kaufpreis besteht eine starke positive Korrelation mit einem Korrelationskoeffizienten von *r = 0.79*. Auch der variable Hypothekarzins (Median) zeigt eine vergleichbar hohe Korrelation zum Kaufpreis (*r = 0.77*). Die beiden Zinssätze selbst korrelieren mit *r = 0.88*, was auf eine gemeinsame geldpolitische Steuerung oder eine hohe Marktkopplung hinweist.
#
# Ein besonders aufschlussreiches Bild ergibt sich aus dem kombinierten Zeitreihendiagramm mit dualer y-Achse. Die monatliche Entwicklung der Median-Kaufpreise und des Median-Zinssatzes über den gesamten Untersuchungszeitraum lässt sich in drei markante Phasen unterteilen:
#
# **Stabile Phase (2018–2021):** In dieser Phase blieben die Hypothekarzinsen auf einem niedrigen und stabilen Niveau, während die Kaufpreise moderat anstiegen.
#
# **Zins- und Preisanstieg (2022–Mitte 2023):** Beide Variablen stiegen deutlich. Dies widerspricht der klassischen Zins-Preis-Logik und deutet auf zusätzliche Einflussfaktoren wie Inflationsschutz durch Immobilien, Nachfrageüberhänge oder begrenztes Angebot hin.
#
# **Zinssenkung bei stabilen Preisen (Ende 2023–2024):** Die Zinsen sanken wieder, während die Kaufpreise auf hohem Niveau verharrten, ein mögliches Indiz für strukturelle Marktveränderungen oder eine verzögerte Preisanpassung.
#
# Diese Resultate zeigen, dass der Einfluss der Zinsen auf die Immobilienpreise nicht isoliert kausal betrachtet werden kann. Vielmehr ist von einem multikausalen Wirkungszusammenhang auszugehen, bei dem auch makroökonomische Faktoren, Erwartungen der Marktteilnehmenden und externe Schocks (z. B. Inflation, Angebotsschocks) eine zentrale Rolle spielen.

# %% [markdown]
# ### 4.2.2 Kaufpreis vs. Inflation (jährlich)
#
# Im zweiten Schritt wird der Median der Kaufpreise pro Jahr berechnet und mit den jährlichen Inflationsdaten des Bundesamts für Statistik (LIK) zusammengeführt. Da die Inflationsdaten nur auf Jahresbasis vorliegen, erfolgt auch die Aggregation der Kaufpreise entsprechend auf Jahressicht.
#
# Ziel ist es, mögliche längerfristige Zusammenhänge zwischen der allgemeinen Preisentwicklung (Inflation) und der Entwicklung der Immobilienpreise zu identifizieren.

# %%
# Korrelation zwischen Kaufpreis und Inflation (LIK)
correlation = dhService.df_merge_inflation[['median_kaufpreis', 'lik']].corr(method='pearson')
display(correlation)
# Out:
#                   median_kaufpreis       lik
# median_kaufpreis          1.000000  0.769504
# lik                       0.769504  1.000000

# %%
plt.figure(figsize=(8, 6))
sns.regplot(
    x='lik',
    y='median_kaufpreis',
    data=dhService.df_merge_inflation,
    line_kws={'color': 'dodgerblue'},
)

plt.title('Zusammenhang zwischen Inflation (LIK) und Median-Kaufpreisen (jährlich, 2018–2023)')
plt.xlabel('Inflation LIK [%]')
plt.ylabel('Median-Kaufpreis [CHF]')

# Tausendertrennzeichen im Schweizer Format auf Y-Achse
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:,.0f}".replace(",", "'")))

plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12, 5))

# Linke Y-Achse: Median-Kaufpreis
ax1.plot(dhService.df_merge_inflation['jahr'], dhService.df_merge_inflation['median_kaufpreis'],
         color='dodgerblue', marker='o', label='Median-Kaufpreis')
ax1.set_ylabel('Kaufpreis [CHF]', color='dodgerblue')
ax1.tick_params(axis='y', labelcolor='dodgerblue')
ax1.grid(True)  # Nur hier Grid aktivieren

# Rechte Y-Achse: Inflation LIK
ax2 = ax1.twinx()
ax2.plot(dhService.df_merge_inflation['jahr'], dhService.df_merge_inflation['lik'],
         color='turquoise', marker='s', linestyle='--', label='Inflation LIK')
ax2.set_ylabel('Inflation LIK [%]', color='turquoise')
ax2.tick_params(axis='y', labelcolor='turquoise')
ax2.grid(False)  # Grid hier deaktivieren

# Allgemeine Formatierung
ax1.set_xlabel('Jahr')
plt.title('Vergleich: Median-Kaufpreis und Inflation (LIK) pro Jahr')

# Legende für beide Achsen anzeigen
fig.legend(loc='upper left', bbox_to_anchor=(0.11, 0.9))

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation der Ergebnisse zu Kapitel 4.2.2
#
# Die Analyse auf Jahresbasis zeigt einen deutlich positiven Zusammenhang zwischen der Inflationsrate (LIK) und dem Median der Immobilienkaufpreise im Zeitraum von 2018 bis 2023. Die berechnete Pearson-Korrelation von **r = 0.77** weist auf einen klaren linearen Zusammenhang zwischen der allgemeinen Preisentwicklung (Inflation) und den Immobilienpreisen hin.
#
# Auch der Scatterplot mit Regressionslinie unterstreicht diese Beziehung: Je höher die Inflationsrate (LIK), desto höher tendieren auch die Median-Kaufpreise für Immobilien. Diese Beobachtung lässt sich ökonomisch plausibel erklären.
#
# In Phasen erhöhter Inflation dienen Immobilien häufig als Sachwertanlage und Inflationsschutz, was die Nachfrage nach Wohnraum verstärken kann. Parallel dazu steigen auch die Baukosten und Transaktionskosten, was die Immobilienpreise zusätzlich nach oben treiben dürfte. Beide Mechanismen wirken in dieselbe Richtung und stützen die beobachtete Korrelation.
#
# In Jahren mit sehr niedriger oder negativer Inflation, beispielsweise im Jahr 2020 mit einer LIK-Veränderung von –0.7 %, zeigt sich hingegen eine deutlich moderatere Preisentwicklung auf dem Immobilienmarkt. Diese Ausnahme bestätigt die Regel und stärkt die Interpretation einer direkten Verbindung zwischen Inflation und Immobilienpreisen.
#
# Gleichzeitig ist zu betonen, dass Inflation zwar ein relevanter Einflussfaktor ist, aber nicht isoliert wirkt. Die Preisentwicklung wird vielmehr durch ein Zusammenspiel weiterer Variablen bestimmt, wie etwa Zinsen, verfügbare Haushaltseinkommen oder das Angebot am Immobilienmarkt.

# %% [markdown]
# ### 4.2.3 Kaufpreis vs. Immobilienpreisindex (quartalsweise)
#
# Im dritten Analyseschritt wird der Median der Immobilienkaufpreise pro Quartal berechnet und mit dem Wohnimmobilienpreisindex (IMPI) verglichen. Der IMPI basiert auf realen Transaktionsdaten und bildet die Preisentwicklung von Wohneigentum in der Schweiz quartalsweise ab. Durch die zeitlich feine Auflösung bietet sich der IMPI besonders zur Analyse kurzfristiger Preisveränderungen an.
#
# Da die IMPI-Daten quartalsweise vorliegen (z. B. Q1, Q2 etc.), wurden auch die Kaufpreisdaten auf Quartalsbasis aggregiert. Anschliessend erfolgte ein Merge beider Datensätze über die gemeinsamen Attribute Jahr und Quartal.
#
# Ziel ist es, mögliche dynamische Zusammenhänge zwischen dem IMPI und den Median-Kaufpreisen auf Quartalsbasis zu identifizieren.

# %%
# Korrelation berechnen
correlation_impi = dhService.df_merge_impi[['median_kaufpreis', 'total']].corr(method='pearson')
correlation_impi.rename(columns={'total': 'impi_index'}, inplace=True)
display(correlation_impi)
# Out:
#                   median_kaufpreis  impi_index
# median_kaufpreis          1.000000    0.954093
# total                     0.954093    1.000000

# %%
# Stil setzen
sns.set(style="whitegrid")

# Scatterplot mit Regressionslinie
plt.figure(figsize=(8, 6))
sns.regplot(x='total', y='median_kaufpreis', data=dhService.df_merge_impi,
            line_kws={'color': 'dodgerblue'}, scatter_kws={'s': 30})
plt.title('Zusammenhang: Wohnimmobilienpreisindex (IMPI) vs. Median-Kaufpreis')
plt.xlabel('IMPI [Totalindex]')
plt.ylabel('Median-Kaufpreis [CHF]')

# Tausendertrennzeichen im Schweizer Format auf Y-Achse
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:,.0f}".replace(",", "'")))

plt.tight_layout()
plt.show()

# %%
# Formatierte X-Achse mit Jahr und Quartal kombiniert (z. B. 2018Q1, 2018Q2 etc.)
dhService.df_merge_impi['quartal_label'] = dhService.df_merge_impi['jahr'].astype(str) + 'Q' + dhService.df_merge_impi['quartal'].astype(str)

# Plot
fig, ax1 = plt.subplots(figsize=(12, 5))

# Linke Y-Achse: Median-Kaufpreis
ax1.plot(dhService.df_merge_impi['quartal_label'], dhService.df_merge_impi['median_kaufpreis'],
         color='dodgerblue', marker='o', label='Median-Kaufpreis')
ax1.set_ylabel('Kaufpreis [CHF]', color='dodgerblue')
ax1.tick_params(axis='y', labelcolor='dodgerblue')
ax1.grid(True)

# Rechte Y-Achse: IMPI
ax2 = ax1.twinx()
ax2.plot(dhService.df_merge_impi['quartal_label'], dhService.df_merge_impi['total'],
         color='turquoise', marker='s', linestyle='--', label='IMPI')
ax2.set_ylabel('IMPI [Totalindex]', color='turquoise')
ax2.tick_params(axis='y', labelcolor='turquoise')
ax2.grid(False)

# X-Achse formatieren
ax1.set_xticks(dhService.df_merge_impi['quartal_label'])
ax1.set_xticklabels(dhService.df_merge_impi['quartal_label'], rotation=45, ha='right')

# Titel und Layout
ax1.set_xlabel('Quartal')
plt.title('Vergleich: Median-Kaufpreis und Wohnimmobilienpreisindex (IMPI) pro Quartal')

# Legende für beide Achsen anzeigen
fig.legend(loc='upper left', bbox_to_anchor=(0.11, 0.9))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation der Ergebnisse zu Kapitel 4.2.3
#
# Die Analyse auf Quartalsbasis zeigt einen sehr starken positiven Zusammenhang zwischen dem Median-Kaufpreis für Immobilien und dem Wohnimmobilienpreisindex (IMPI). Die berechnete Pearson-Korrelation beträgt **r = 0.95**, was auf eine nahezu perfekte lineare Beziehung zwischen den beiden Variablen hinweist.
#
# Auch der Scatterplot mit Regressionslinie bestätigt diese starke Korrelation: Ein steigender IMPI geht tendenziell mit einem Anstieg der Median-Kaufpreise einher. Diese Parallelentwicklung deutet darauf hin, dass sich die aggregierten Transaktionspreise (Median-Kaufpreise) am Markt weitgehend synchron zur Entwicklung des amtlichen Preisindexes für Wohneigentum bewegen.
#
# Das Liniendiagramm unterstreicht zusätzlich diese Beobachtung: Die Zeitreihen beider Variablen verlaufen nahezu parallel, wobei es nur geringfügige Abweichungen in einzelnen Quartalen gibt. Dies spricht für eine hohe Übereinstimmung zwischen amtlicher Preisbeobachtung und realem Marktgeschehen.
#
# Ökonomisch betrachtet erscheint dieses Ergebnis plausibel, da der IMPI auf realen Verkaufsdaten basiert und somit die tatsächliche Marktdynamik gut widerspiegelt. Die starke Kopplung beider Variablen legt nahe, dass sich der IMPI als zuverlässiger Referenzwert für die Entwicklung der Immobilienpreise eignet, insbesondere bei Analysen mit hoher zeitlicher Auflösung wie auf Quartalsbasis.

# %% [markdown]
# ## 4.3 Deskriptive Analyse (Trends, Verteilungen)
#
# Im Rahmen der deskriptiven Analyse werden zentrale Kennwerte der relevanten Variablen auf Jahresbasis untersucht, um mögliche Entwicklungen und Verteilungen zwischen 2018 und 2023 sichtbar zu machen. Im Fokus stehen dabei insbesondere:
#
# - Der Median der Immobilienkaufpreise (basierend auf Transaktionen),
# - Der durchschnittliche Hypothekarzinssatz (aggregiert aus Monatsdaten),
# - Der jährliche Landesindex der Konsumentenpreise (LIK) sowie
# - Der durchschnittliche Wohnimmobilienpreisindex (IMPI, aggregiert aus Quartalen).
#
# Durch die jährliche Aggregation lassen sich allgemeine Trends in den Variablen nachvollziehen und erste Hypothesen über mögliche Zusammenhänge zwischen Zinsentwicklung, Inflation und Immobilienpreisen ableiten.
#
# Ziel dieser deskriptiven Auswertung ist es, die Basis für die anschliessende Korrelationsanalyse zu legen, indem die zentralen Verläufe der Einflussgrössen auf den Schweizer Immobilienmarkt über einen konsistenten Zeitraum hinweg sichtbar gemacht werden.

# %%
# Jahresbereich definieren
zeitraum = list(range(2018, 2024))  # 2024 lassen wir bewusst weg wegen IMPI/Inflation

# Median-Kaufpreis pro Jahr (bereits vorhanden, aber zur Sicherheit nochmals definieren)
yearly_prices = (
    dhService.dfDataHiveCleaned[dhService.dfDataHiveCleaned['jahr'].isin(zeitraum)]
    .groupby('jahr')['purchase_price']
    .median()
    .reset_index(name='median_kaufpreis')
)

# Durchschnittlicher Zins pro Jahr berechnen
yearly_zins = (
    dataService.dfHypo[dataService.dfHypo['jahr'].isin(zeitraum)]
    .groupby('jahr')['festhypo_mittelwert']
    .mean()
    .reset_index()
)

# Durchschnittlicher IMPI pro Jahr (aus Quartalen)
df_impi_yearly = (
    dataService.dfWohn[dataService.dfWohn['jahr'].isin(zeitraum)]
    .groupby('jahr')['total']
    .mean()
    .reset_index()
    
)

# Alle zusammenführen
df_merge_all = (
    yearly_prices
    .merge(yearly_zins, on='jahr', how='left')
    .merge(dataService.dfLik, on='jahr', how='left')
    .merge(df_impi_yearly, on='jahr', how='left')
    .drop(columns=['id', 'hvpi'])  
    .rename(columns={'festhypo_mittelwert': 'zins_durchschnitt'})  
    .rename(columns={'total': 'impi_durchschnitt'})
)

# Ergebnis anzeigen
display(df_merge_all)
# Out:
#    jahr  median_kaufpreis  zins_durchschnitt  lik  impi_durchschnitt
# 0  2018          720000.0           1.354158  0.9          94.953750
# 1  2019          725000.0           1.112392  0.4          98.508875
# 2  2020          730000.0           1.055568 -0.7         100.946325
# 3  2021          760000.0           1.019538  0.6         106.725500
# 4  2022          800000.0           1.702875  2.8         113.525500
# 5  2023          845000.0           2.492908  2.1         116.021500

# %%
# Min-Max-Normalisierung für alle Spalten (außer Jahr)
scaler = MinMaxScaler()
scaled_values = scaler.fit_transform(df_merge_all.drop(columns='jahr'))
df_scaled = pd.DataFrame(scaled_values, columns=df_merge_all.columns[1:])
df_scaled['jahr'] = df_merge_all['jahr']
colors = ['dodgerblue', 'forestgreen', 'turquoise', 'teal', 'darkviolet']

# Plot erstellen
plt.figure(figsize=(12, 6))
for col, color in zip(['median_kaufpreis', 'zins_durchschnitt', 'lik', 'impi_durchschnitt'], colors):
    if col == 'lik':
        label = col.upper()
    elif col == 'impi_durchschnitt':
        label = 'IMPI Durchschnitt'
    else:
        label = col.replace('_', ' ').title()    
    plt.plot(df_scaled['jahr'], df_scaled[col], label=label, marker='o', color=color)

plt.title('Normierter Vergleich: Kaufpreis, Zins, LIK und IMPI (2018–2023)')
plt.xlabel('Jahr')
plt.ylabel('Skalierter Wert (0–1)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation der Ergebnisse zu Kapitel 4.3
#
# Im Rahmen der deskriptiven Analyse wurde der Median der Kaufpreise pro Jahr mit drei externen Einflussgrössen zusammengeführt: dem durchschnittlichen Hypothekarzinssatz (monatlich aggregiert), der Inflation (LIK, jährlich) sowie dem Immobilienpreisindex (IMPI, quartalsweise aggregiert). Um diese heterogenen Grössen vergleichbar zu machen, erfolgte eine Min-Max-Normalisierung aller Variablen auf einen Skalenbereich zwischen 0 und 1. Dies erlaubte es, die vier zeitlichen Entwicklungen zwischen 2018 und 2023 in einem einheitlichen Diagramm gegenüberzustellen.
#
# Die folgende Interpretation basiert auf dem normierten Liniendiagramm:
#
# - Median-Kaufpreise zeigen einen klaren, nahezu linearen Aufwärtstrend über den gesamten Zeitraum, mit einer besonders starken Zunahme ab 2021.
#
# - IMPI (Indexwert) verläuft insgesamt parallel zur Kaufpreisentwicklung, mit einer stetigen Zunahme und deutlicher Korrelation, insbesondere ab 2020.
#
# - Zinssätze blieben zunächst konstant niedrig, stiegen jedoch ab 2022 deutlich an, eine Entwicklung, die dem Anstieg der Kaufpreise erst verzögert folgt.
#
# - Inflation (LIK) ist zwischen 2020 und 2022 stark angestiegen und verläuft in Teilen synchron mit den Zinsen. Die Entwicklung ist jedoch volatiler als jene der Kaufpreise oder des IMPI.
#
# Bedeutung der Transformation:
# Die Min-Max-Skalierung war essenziell, um Variablen mit unterschiedlichen Einheiten (z. B. CHF, %, Indexwerte) visuell vergleichbar zu machen. Ohne diese Transformation wären gemeinsame Trends nicht interpretierbar gewesen, da die Kaufpreise nominal deutlich höher und weniger empfindlich auf Prozentänderungen reagieren als etwa Inflationsraten.
#
# Vorläufige Hypothesen aus der Trendanalyse Zinsentwicklung scheinen erst ab 2022 in spürbarem Masse mit den Kaufpreisen zu interagieren. Der Einfluss ist zeitlich verzögert.
#
# Inflation verläuft nur teilweise synchron mit der Kaufpreisentwicklung, was auf andere Einflussfaktoren (z. B. Marktknappheit, Nachfrage) hindeuten könnte.
#
# Der IMPI ist der Einflussgrösse mit der sichtbar höchsten Parallelität zum Kaufpreis, was die Plausibilität des Index als Referenz für die Marktentwicklung bestätigt.

# %% [markdown]
# ## 4.4 Korrelationsanalyse (Matrix, Scatterplots)
#
# Aufbauend auf der deskriptiven Analyse in Kapitel 4.3 erfolgt im vierten Analyseschritt eine Korrelationsanalyse zwischen den jährlich aggregierten Einflussgrössen und den Immobilienkaufpreisen. Ziel ist es, statistische Zusammenhänge zwischen den untersuchten Variablen systematisch zu identifizieren und visuell darzustellen.
#
# Dabei kommen zwei Methoden zum Einsatz:
#
# - Eine **Korrelationsmatrix** auf Basis des Pearson-Korrelationskoeffizienten, um lineare Zusammenhänge zwischen allen vier Variablen (Kaufpreis, Zins, Inflation, IMPI) zu analysieren.
# - **Scatterplots** mit Regressionslinie für den gezielten Vergleich des Kaufpreises mit den Einflussgrössen.
#
# Die Grundlage der Analyse bildet dasselbe normalisierte Dataset aus Kapitel 4.3. Damit wird sichergestellt, dass alle Variablen im gleichen Wertebereich liegen und keine Verzerrung durch unterschiedliche Skalen (CHF, %, Index) entsteht.
#
# Die Analyse hilft, Hypothesen aus der deskriptiven Betrachtung quantitativ zu überprüfen, etwa ob der IMPI tatsächlich am stärksten mit den Immobilienkaufpreisen korreliert, oder ob Zinssätze eine verzögerte, aber dennoch relevante Rolle spielen.
#
# #### 4.4.1 Korrelationsmatrix (Pearson)
#
# Zur quantitativen Analyse möglicher linearer Zusammenhänge zwischen den jährlich aggregierten Einflussgrössen wird die Pearson-Korrelationsmatrix erstellt. Diese zeigt die Stärke und Richtung der linearen Beziehung zwischen den betrachteten Variablen.

# %%
# Korrelationsmatrix berechnen (nur numerische Werte)
correlation_matrix = df_merge_all.drop(columns='jahr').corr(method='pearson')

# Matrix anzeigen mit dem Ziel: Stärke des linearen Zusammenhangs zwischen Kaufpreis und Einflussfaktoren anzuzeigen (Zins, Inflation, IMPI)
display(correlation_matrix)
# Out:
#                    median_kaufpreis  zins_durchschnitt       lik  \
# median_kaufpreis           1.000000           0.888134  0.769504
# zins_durchschnitt          0.888134           1.000000  0.745155
# lik                        0.769504           0.745155  1.000000
# impi_durchschnitt          0.960420           0.735702  0.727977
#
#                    impi_durchschnitt
# median_kaufpreis            0.960420
# zins_durchschnitt           0.735702
# lik                         0.727977
# impi_durchschnitt           1.000000

# %% [markdown]
# #### 4.4.2 Visualisierung der Korrelationen (Heatmap)
#
# Die folgenden Heatmap stellt die berechnete Pearson-Korrelationsmatrix visuell dar. Farbverläufe helfen dabei, besonders starke oder schwache Zusammenhänge schnell zu erkennen.

# %%
# Stil setzen
sns.set(style='white', font_scale=1.1)

# Spaltennamen vereinfachen (nur für Darstellung, verändert df_merge_all nicht)
renamed_matrix = correlation_matrix.copy()
renamed_matrix.columns = ['Kaufpreis Median', 'Zins Ø', 'Inflation LIK', 'IMPI Ø']
renamed_matrix.index = ['Kaufpreis Median', 'Zins Ø', 'Inflation LIK', 'IMPI Ø']

# Heatmap mit vereinfachter Beschriftung erstellen
plt.figure(figsize=(8, 6))
sns.heatmap(renamed_matrix, annot=True, cmap='PuBu', center=0, fmt=".2f", linewidths=0.5)

plt.title('Korrelationsmatrix: Kaufpreis, Zins, Inflation, IMPI (2018–2023)')
plt.xticks(rotation=45)  # X-Achsen-Beschriftung schräg
plt.yticks(rotation=0)   # Y-Achsen-Beschriftung horizontal
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.4.3 Visualisierung ausgewählter Zusammenhänge (Scatterplots)
#
# Zur genaueren Betrachtung einzelner Korrelationen werden im Folgenden Scatterplots mit Regressionslinien erstellt. Dies erlaubt eine visuelle Einschätzung, ob ein linearer Zusammenhang zwischen zwei Variablen vorliegt.
#
# Der Vergleich mit der Inflation wurde aufgrund der vergleichsweise geringen Korrelation (r = 0.77) nicht als Scatterplot umgesetzt, sondern nur über die Pearson-Korrelation bewertet und in der Heatmap visualisiert. Die Datenbasis (Jahre 2018–2023) wäre grundsätzlich ausreichend gewesen, wurde jedoch nicht weiterverwendet, da im Vergleich zu IMPI und Zins keine eindeutige lineare Beziehung erkennbar war.

# %%
# Scatterplot mit Regressionslinie: Kaufpreis vs. IMPI
plt.figure(figsize=(6, 5))
sns.regplot(x='impi_durchschnitt', y='median_kaufpreis', data=df_merge_all,
            line_kws={'color': 'dodgerblue'}, scatter_kws={'s': 40})
plt.title('Zusammenhang: Median-Kaufpreis vs. IMPI (2018–2023)')
plt.xlabel('IMPI [Totalindex]')
plt.ylabel('Median-Kaufpreis [CHF]')
plt.grid(True)

# Tausendertrennzeichen im Schweizer Format auf Y-Achse
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:,.0f}".replace(",", "'")))

plt.tight_layout()
plt.show()

# %%
# Scatterplot mit Regressionslinie: Kaufpreis vs. Zins
plt.figure(figsize=(6, 5))
sns.regplot(x='zins_durchschnitt', y='median_kaufpreis', data=df_merge_all,
            line_kws={'color': 'dodgerblue'}, scatter_kws={'s': 40})
plt.title('Zusammenhang: Median-Kaufpreis vs. Zins (2018–2023)')
plt.xlabel('Zinssatz [%]')
plt.ylabel('Median-Kaufpreis [CHF]')
plt.grid(True)

# Tausendertrennzeichen im Schweizer Format auf Y-Achse
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:,.0f}".replace(",", "'")))

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Interpretation der Ergebnisse zu Kapitel 4.4
#
# Im Rahmen der Korrelationsanalyse wurde auf Jahresbasis untersucht, inwieweit zentrale Einflussgrössen wie Hypothekarzinssätze, Inflation (LIK) und der Wohnimmobilienpreisindex (IMPI) statistisch mit dem Median der Kaufpreise von Wohnimmobilien in der Schweiz zwischen 2018 und 2023 korrelieren. Als Grundlage dienten der aggregierte Datensatz `df_merge_all` sowie Pearson-Korrelationskoeffizienten und unterstützende Scatterplots mit Regressionslinien.
#
# Der Vergleich mit der Inflation wurde aufgrund der vergleichsweise geringen Korrelation (r = 0.77) nicht als Scatterplot umgesetzt, sondern nur über die Pearson-Korrelation bewertet und in der Heatmap visualisiert. Die Datenbasis (Jahre 2018–2023) wäre grundsätzlich ausreichend gewesen, wurde jedoch nicht weiterverwendet, da im Vergleich zu IMPI und Zins keine eindeutige lineare Beziehung erkennbar war.
#
#
#
# Die Korrelationsmatrix zeigt folgende zentrale Ergebnisse:
#
# - **IMPI vs. Kaufpreis**: Der höchste Korrelationswert wurde zwischen dem IMPI und dem Median-Kaufpreis beobachtet (r = 0.96). Diese sehr starke positive Korrelation bestätigt, dass der offizielle Index des Bundesamtes für Statistik die reale Preisentwicklung am Immobilienmarkt sehr gut abbildet. Auch der Scatterplot zeigt eine nahezu lineare Beziehung.
#
# - **Zinssatz vs. Kaufpreis**: Die Korrelation zwischen dem mittleren Hypothekarzinssatz und dem Median-Kaufpreis liegt bei r = 0.89. Trotz des hohen Werts ist zu beachten, dass der Einfluss des Zinses zeitverzögert eintreten kann, was sich auch in der Regression durch eine stärkere Streuung widerspiegelt. Dies deutet auf eine mögliche indirekte oder verzögerte Wirkung hin, zum Beispiel über die Beeinflussung der Nachfrage.
#
# - **Inflation vs. Kaufpreis**: Mit einem Korrelationswert von r = 0.77 besteht auch zwischen Inflation und Kaufpreisen ein positiver Zusammenhang, allerdings deutlich schwächer als bei IMPI oder Zinssatz. Die Volatilität der Inflation (z. B. negativer Wert im Jahr 2020) könnte die statistische Beziehung verringert haben.
#
# - **Zusammenhang unter Einflussgrössen**: Auch zwischen den erklärenden Variablen bestehen teils starke Zusammenhänge, insbesondere zwischen Zinsen und Inflation (r = 0.75), was auf makroökonomische Wechselwirkungen hindeutet.
#
#
#
# Die eingesetzten Scatterplots mit Regressionslinie unterstreichen diese Erkenntnisse visuell. Der Plot **IMPI vs. Kaufpreis** zeigt eine dichte Punktwolke entlang der Regressionslinie, während der Plot **Zins vs. Kaufpreis** eine grössere Streuung aufweist, was mit der ökonomischen Annahme eines zeitverzögerten Zinseffekts konsistent ist.
#
#
#
# **Fazit**
#
# Die Korrelationsanalyse auf Jahresbasis liefert erste quantifizierbare Hinweise auf Zusammenhänge zwischen makroökonomischen Grössen und der Preisentwicklung auf dem Schweizer Immobilienmarkt. Besonders der **IMPI** zeigt sich als verlässlicher Indikator für reale Transaktionspreise. Die **Hypothekarzinsen** gewinnen ab 2022 deutlich an Relevanz, während der Einfluss der **Inflation** als begrenzt, aber vorhanden einzuschätzen ist. Die folgenden Korrelationen wurden im Hinblick auf den strategischen Analysebedarf der Publica Pensionskasse durchgeführt, um datenbasierte Hinweise zur zukünftigen Investitionsstrategie im Immobiliensektor zu identifizieren.

# %% [markdown]
# # 5. Forecasting & Zeitreihenanalyse
# *(CPA Step 3: Analyzing data)*
#
# Auf Basis der in Kapitel 4 identifizierten Zusammenhänge zwischen Kaufpreisen, Zinsen, Immobilienpreisindex und Inflation wird in diesem Abschnitt untersucht, inwieweit sich die beobachteten Entwicklungen fortschreiben lassen. Ziel ist es, mit Hilfe statistischer Zeitreihenmodelle eine Prognose der zukünftigen Preisentwicklung auf dem Schweizer Immobilienmarkt zu erstellen.
#
# Die Analyse konzentriert sich auf die aggregierten **monatlichen Median-Kaufpreise** aus dem DataHive-Datensatz, die den Zeitraum **Januar 2018 bis März 2025** abdecken. Prognosemodelle wie ARIMA, SARIMA und SARIMAX eignen sich gut, um solche zeitlich strukturierten Daten zu analysieren, insbesondere bei erwartbaren Trends oder saisonalen Mustern.
#
# Dieses Kapitel umfasst alle notwendigen Schritte zur Vorbereitung und Durchführung der Zeitreihenanalyse, von der Prüfung der Stationarität über die Modellierung bis zur Bewertung der Forecasts.
#
# ## 5.1 Zielsetzung und Methodik
#
# Das Ziel dieses Abschnitts ist es, auf Basis der Zeitreihe `median_kaufpreis` aus dem DataHive-Datensatz eine fundierte Prognose der zukünftigen Immobilienpreisentwicklung zu generieren. Dabei kommen bewährte Modelle der Zeitreihenanalyse zum Einsatz, wie sie auch im Unterricht thematisiert wurden.
#
# Die methodische Umsetzung orientiert sich an der CPA-Vorgehensweise und umfasst folgende Schritte:
#
# 1. **Visuelle und statistische Prüfung der Stationarität** der Zeitreihe mittels Zeitreihendiagramm und ADF-Test (Augmented Dickey-Fuller).
# 2. **Bestimmung geeigneter Modellparameter** mit Hilfe von ACF- und PACF-Plots (Autoregression und gleitender Durchschnitt).
# 3. **Modellauswahl**: Vergleich von ARIMA-, SARIMA- und SARIMAX-Modellen, abhängig von der Saisonalität der Daten.
# 4. **Train-Test-Split und Forecasting**: Training auf historischen Daten, Prognose bis März 2025.
# 5. **Modellbewertung**: Analyse der Prognosegüte mittels MAE und RMSE.
#
# Die Analyse wird vollständig in Python durchgeführt (Bibliotheken: `statsmodels`, `pmdarima`). Besonderer Wert wird dabei auf Transparenz, Reproduzierbarkeit und ökonomische Interpretierbarkeit gelegt.
#
# ## 5.2 Stationarität prüfen
#
# ARIMA-, SARIMA- und SARIMAX-Modelle setzen stationäre Zeitreihen voraus. Daher prüfen wir zunächst, ob die Zeitreihe `median_kaufpreis` im Zeitraum 2018–2025 diese Voraussetzung erfüllt. Stationarität liegt vor, wenn sich statistische Eigenschaften wie Mittelwert, Varianz und Autokorrelation im Zeitverlauf nicht systematisch verändern.
#
# Da Preisreihen wie Immobilienkaufpreise häufig **nicht stationär** sind (z. B. wegen langfristiger Trends oder saisonaler Effekte), ist eine Kombination aus visueller und statistischer Prüfung erforderlich. Falls Stationarität nicht gegeben ist, wenden wir Transformationen wie **Differenzierung** an.
#
# Für die Prüfung kommen folgende Schritte zum Einsatz:
# - **Zeitreihendiagramm der Median-Kaufpreise**, um visuelle Hinweise auf Trends oder Instabilität zu erkennen.
# - **Augmented Dickey-Fuller-Test (ADF)** zur quantitativen Beurteilung der Stationarität.
# - **Einmalige oder mehrfache Differenzierung**, um stationäre Eigenschaften herzustellen.
#
# Die Analyse erfolgt auf Basis des vorbereiteten DataFrames `monthly_prices`, der in Kapitel 4 aggregiert wurde.

# %%
# Wir erstellen einen separaten Forecast-DataFrame auf Monatsbasis mit dem vollen Kaufpreis-Zeitraum (bis März 2025)

# Datum sicherstellen
dhService.dfDataHiveCleaned['activated'] = pd.to_datetime(dhService.dfDataHiveCleaned['activated'], errors='coerce')

# Neue Spalten für Jahr und Monat erstellen
dhService.dfDataHiveCleaned['year'] = dhService.dfDataHiveCleaned['activated'].dt.year
dhService.dfDataHiveCleaned['month'] = dhService.dfDataHiveCleaned['activated'].dt.month

# Aggregieren: Median-Kaufpreis pro Monat (2018–2025)
monthly_prices_forecast = (
    dhService.dfDataHiveCleaned
    .groupby(['year', 'month'])['purchase_price']
    .median()
    .reset_index()
    .rename(columns={'purchase_price': 'median_kaufpreis'})
)

# Datum für Zeitreihenmodell als Index erstellen
monthly_prices_forecast['date'] = pd.to_datetime(
    monthly_prices_forecast['year'].astype(str) + '-' + monthly_prices_forecast['month'].astype(str)
)
monthly_prices_forecast.set_index('date', inplace=True)

# Zeitraum anzeigen zur Kontrolle
print("Forecast-Zeitraum von", monthly_prices_forecast.index.min().date(), "bis", monthly_prices_forecast.index.max().date())

# Wir visualisieren die Zeitreihe der Median-Kaufpreise von 2018–2025 zur visuellen Einschätzung von Trend, Schwankungen und Saisonalität

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(monthly_prices_forecast.index, monthly_prices_forecast['median_kaufpreis'], marker='o', color='dodgerblue')
plt.title("Median-Kaufpreise (monatlich, 2018–2025)")
plt.xlabel("Zeit")
plt.ylabel("Kaufpreis [CHF]")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Forecast-Zeitraum von 2018-01-01 bis 2025-03-01

# %% [markdown]
# #### 5.2.1 ADF-Test zur statistischen Überprüfung
#
# Der Augmented Dickey-Fuller-Test (ADF-Test) ist ein Standardverfahren zur Prüfung der Nullhypothese, dass eine Zeitreihe ein Einheitswurzelprozess (nicht stationär) ist.
#
# Wenn der **p-Wert kleiner als 0.05** ist, lehnen wir die Nullhypothese ab und können davon ausgehen, dass die Zeitreihe **stationär** ist. Andernfalls sind weitere Transformationen (z. B. Differenzierung) nötig.
#
# Wir führen den Test auf der Spalte `median_kaufpreis` aus dem DataFrame `monthly_prices` durch.

# %%
# Wir führen den Augmented Dickey-Fuller-Test (ADF) auf der Spalte 'median_kaufpreis' durch

# ADF-Test durchführen
adf_result = adfuller(monthly_prices_forecast['median_kaufpreis'].dropna())

# Ergebnis interpretieren
print("ADF-Teststatistik:", round(adf_result[0], 3))
print("p-Wert:", round(adf_result[1], 4))
print("Kritische Werte:")
for key, value in adf_result[4].items():
    print(f"  {key}: {round(value, 3)}")
# Out:
# ADF-Teststatistik: -0.329
# p-Wert: 0.9213
# Kritische Werte:
#   1%: -3.516
#   5%: -2.899
#   10%: -2.587

# %% [markdown]
# #### Interpretation zur statistischen Überprüfung
#
# Die Visualisierung der Zeitreihe der `median_kaufpreis`-Werte von Januar 2018 bis März 2025 zeigt einen deutlich erkennbaren Aufwärtstrend mit saisonalen Schwankungen. Diese Entwicklung lässt auf eine ökonomisch plausible, aber **nicht stationäre** Zeitreihe schliessen, da weder Mittelwert noch Varianz über den Zeitraum konstant erscheinen.
#
# Dieses visuelle Ergebnis wird durch den **Augmented Dickey-Fuller-Test (ADF)** statistisch bestätigt. Mit einer **ADF-Teststatistik von –0.329** und einem **p-Wert von 0.9213** liegt der p-Wert deutlich über dem Signifikanzniveau von 0.05. Damit kann die Nullhypothese (nicht stationär) **nicht verworfen** werden, und wir gehen davon aus, dass die Zeitreihe **nicht stationär** ist.
#
# Für die weitere Modellierung (z. B. ARIMA/SARIMA) ist daher eine Transformation der Zeitreihe, typischerweise durch Differenzierung, erforderlich um die Stationaritätsannahme herzustellen.

# %%
# Wir differenzieren die Zeitreihe (1. Ordnung), um Trendkomponenten zu entfernen und Stationarität zu erreichen.

# Erste Differenz berechnen
monthly_prices_diff = monthly_prices_forecast['median_kaufpreis'].diff().dropna()

# Visualisierung der differenzierten Zeitreihe
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(monthly_prices_diff, marker='o', linestyle='-', color='dodgerblue')
plt.title("1. Differenz der Median-Kaufpreise (monatlich, 2018–2025)")
plt.xlabel("Zeit")
plt.ylabel("Veränderung des Median-Kaufpreises [CHF]")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Wir prüfen, ob die differenzierte Zeitreihe nun stationär ist.
# ADF-Test durchführen
adf_result_diff = adfuller(monthly_prices_diff)

# Ergebnis interpretieren
print("ADF-Teststatistik:", round(adf_result_diff[0], 3))
print("p-Wert:", round(adf_result_diff[1], 4))
print("Kritische Werte:")
for key, value in adf_result_diff[4].items():
    print(f"  {key}: {round(value, 3)}")
# Out:
# ADF-Teststatistik: -5.402
# p-Wert: 0.0
# Kritische Werte:
#   1%: -3.516
#   5%: -2.899
#   10%: -2.587

# %% [markdown]
# ### Interpretation der Ergebnisse zu Kapitel 5.2.1
#
# Die Visualisierung der ursprünglichen Zeitreihe der Median-Kaufpreise (Kapitel 5.2) zeigt einen klaren Aufwärtstrend mit saisonalen Schwankungen zwischen Januar 2018 und März 2025. Diese Entwicklung deutet ökonomisch auf eine positive Preisentwicklung hin, erfüllt jedoch nicht die Voraussetzung der Stationarität, da weder Mittelwert noch Varianz über die Zeit konstant sind. Die Stationarität ist jedoch eine zentrale Voraussetzung für den Einsatz von ARIMA- oder SARIMA-Modellen.
#
# Der erste Augmented Dickey-Fuller-Test (ADF) bestätigte dieses visuelle Ergebnis statistisch. Mit einer ADF-Teststatistik von **–0.329** und einem **p-Wert von 0.9213** lag der Testwert über allen kritischen Schwellenwerten. Die Nullhypothese der Nicht-Stationarität konnte somit nicht verworfen werden.
#
# Um eine stationäre Eigenschaft herzustellen, wurde die Zeitreihe in einem nächsten Schritt **erstmals differenziert (1. Ordnung)**. Diese Transformation reduziert langfristige Trends und ermöglicht eine Analyse auf Basis der monatlichen Veränderungen der Median-Kaufpreise. Die grafische Darstellung der differenzierten Zeitreihe zeigt stärkere Schwankungen um den Mittelwert und deutet auf das Fehlen eines übergeordneten Trends hin, ein typisches Merkmal stationärer Zeitreihen.
#
# Der anschliessende ADF-Test auf der differenzierten Zeitreihe ergab ein **signifikantes Resultat**:
#
# - ADF-Teststatistik: **–5.402**
# - p-Wert: **0.0**
# - Kritischer Wert bei 1 %: **–3.516**
#
# Da sowohl die ADF-Teststatistik unter allen kritischen Werten liegt als auch der p-Wert kleiner als 0.05 ist, kann die Nullhypothese der Nicht-Stationarität mit hoher Sicherheit verworfen werden. Die Zeitreihe gilt somit als **stationär**.
#
# Mit dieser Bestätigung ist die Voraussetzung für die anschliessende Modellwahl (ARIMA/SARIMA) erfüllt. Die erreichte Stationarität bildet die Grundlage für valide Prognosemodelle, die Publica bei der Ableitung strategischer Investitionsentscheidungen im Immobilienbereich unterstützen können.
#
# ### 5.3 ACF/PACF & Modellwahl

# %%
# Plot erstellen
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# ACF: Moving Average (q) bestimmen
plot_acf(monthly_prices_diff, ax=axes[0], lags=30, color='dodgerblue')
axes[0].set_title("ACF – Autokorrelation der 1. Differenz")

# PACF: Autoregressive Komponente (p) bestimmen
plot_pacf(monthly_prices_diff, ax=axes[1], lags=30, method="ywm", color='dodgerblue')
axes[1].set_title("PACF – Partialautokorrelation der 1. Differenz")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation der Ergebnisse zu Kapitel 5.3
#
# Zur Bestimmung geeigneter Modellparameter für das ARIMA-Modell wurden die Autokorrelationsfunktion (ACF) und die Partialautokorrelationsfunktion (PACF) der differenzierten Kaufpreisdatenreihe (1. Ordnung) analysiert. Ziel war es, erste Hinweise auf sinnvolle Werte für den autoregressiven Anteil (p) sowie den Moving-Average-Anteil (q) zu erhalten.
#
# Der ACF-Plot zeigt ein deutliches Abfallen der Autokorrelation nach dem ersten Lag, was auf eine begrenzte Residualstruktur und einen potenziellen MA(1)-Prozess hinweist. Ab Lag 2 liegen die Werte innerhalb des Konfidenzintervalls, was auf eine geringe Signifikanz weiterer MA-Komponenten schliessen lässt.
#
# Der PACF-Plot weist ebenfalls auf einen starken Abfall nach dem ersten Lag hin. Der signifikante Ausschlag bei Lag 1 deutet auf eine AR(1)-Struktur hin. Auch hier nehmen die weiteren Lags keine signifikanten Werte mehr an, was für einen einfachen autoregressiven Prozess spricht.
#
# **Vorläufige Modellwahl basierend auf ACF/PACF:**
#
# - Differenzierung (d): 1 (stationär nach erster Differenz)
# - Autoregressiver Anteil (p): 1
# - Moving-Average-Anteil (q): 1
#
# Diese Komponenten bilden die Grundlage für das initiale ARIMA(1,1,1)-Modell, das in den folgenden Abschnitten getestet und validiert wird. Die gewählte Modellstruktur ARIMA(1,1,1) ermöglicht es, im nächsten Schritt robuste Prognosen abzuleiten, die als quantitative Entscheidungsgrundlage für die Immobilienstrategie von Publica dienen können.
#
# Hinweis: Weitere positive Ausschläge im PACF bei Lag 12–15 deuten mögliche saisonale Strukturen an, die im späteren SARIMA-Modell (Kapitel 5.4.2) explizit berücksichtigt wurden.
#
# ## 5.4 Modelltraining & Forecast
#
# Ziel dieses Abschnitts ist es, verschiedene Zeitreihenmodelle (ARIMA, SARIMA, SARIMAX) auf Basis der aggregierten Kaufpreisdaten zu trainieren, ihre Prognosegüte zu bewerten und deren Aussagekraft im Kontext strategischer Investitionsentscheidungen einzuschätzen. Die folgenden Unterkapitel zeigen die jeweiligen Modellschritte inklusive Datentransformation, Parameterwahl, Modelltraining und Visualisierung der Prognosewerte.
#
# ### 5.4.1 Modelltraining ARIMA

# %%
# Wir definieren ein ARIMA(1,1,1)-Modell auf Basis der differenzierten Zeitreihe
# wird später verwendet, um bis Dezember 2025 zu prognostizieren

# Stellt sicher, dass die Zeitreihe als monatlich interpretiert wird ('MS' = Month Start), 
# um sauberes Modelltraining und Prognosen ohne Frequenzwarnung zu ermöglichen
monthly_prices_forecast = monthly_prices_forecast.asfreq('MS')

# ARIMA-Modell definieren und fitten
model_arima = ARIMA(monthly_prices_forecast['median_kaufpreis'], order=(1, 1, 1))
model_arima_fit = model_arima.fit()

# Zusammenfassung anzeigen (Modellstatistiken, AIC/BIC etc.)
print(model_arima_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:       median_kaufpreis   No. Observations:                   87
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -971.817
# Date:                Sat, 31 May 2025   AIC                           1949.634
# Time:                        13:43:29   BIC                           1956.997
# Sample:                    01-01-2018   HQIC                          1952.597
#                          - 03-01-2025
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9497      0.017    -55.849      0.000      -0.983      -0.916
# ma.L1          0.9993      0.141      7.088      0.000       0.723       1.276
# sigma2      3.545e+08   3.71e-10   9.55e+17      0.000    3.55e+08    3.55e+08
# ...

# %%
# Prognosehorizont definieren (Anzahl Monate bis Dezember 2025)
forecast_steps = 21  # April 2025 bis Dezember 2025 = 9 Monate + 12 schon abgedeckt

# Prognose erzeugen
forecast_result = model_arima_fit.get_forecast(steps=forecast_steps)
forecast_mean = forecast_result.predicted_mean
forecast_ci = forecast_result.conf_int()

# Datum für Prognosezeitraum erstellen (monatsweise fortlaufend)
last_date = monthly_prices_forecast.index[-1]
forecast_index = pd.date_range(start=last_date + pd.DateOffset(months=1), periods=forecast_steps, freq='MS')
forecast_mean.index = forecast_index
forecast_ci.index = forecast_index

# Visualisierung
plt.figure(figsize=(14, 6))
plt.plot(monthly_prices_forecast.index, monthly_prices_forecast['median_kaufpreis'], label='Beobachtete Werte', color='dodgerblue')
plt.plot(forecast_mean.index, forecast_mean, label='Prognose', color='turquoise')
plt.fill_between(forecast_ci.index, forecast_ci.iloc[:, 0], forecast_ci.iloc[:, 1], color='turquoise', alpha=0.3, label='Konfidenzintervall')
plt.title("ARIMA-Prognose der Median-Kaufpreise (bis Dez. 2025)")
plt.xlabel("Zeit")
plt.ylabel("Kaufpreis [CHF]")

# Y-Achse im Schweizer Format anzeigen (z. B. 900000 statt 900’000 oder 9e5)
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'.replace(",", "")))

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretation der Ergebnisse zu Kapitel 5.4.1
#
# Das ARIMA(1,1,1)-Modell wurde erfolgreich auf Basis der monatlichen Median-Kaufpreise im Zeitraum von Januar 2018 bis März 2025 trainiert. Es besteht aus einem autoregressiven Anteil (AR = 1), einer ersten Differenzierung (d = 1) sowie einem gleitenden Durchschnitt (MA = 1) und basiert auf insgesamt 87 Beobachtungswerten.
#
# Alle Modellparameter (AR1, MA1, sigma²) sind hoch signifikant (p-Wert < 0.001), was auf eine zuverlässige Schätzung hinweist. Die Modellgüte ist laut AIC (1949.634), BIC (1956.997) und HQIC (1952.597) im akzeptablen Bereich. Die Warnhinweise zur Kovarianzmatrix sind bei ökonomischen Zeitreihenmodellen häufig und weisen meist auf hohe Multikollinearität oder geringe Schätzfehler-Varianz hin, sie gelten für einfache Prognosen als unkritisch. Die Ljung-Box-Teststatistik (Q = 8.08, p = 0.00) weist jedoch auf Restautokorrelation hin, was auf eine nicht vollständig adäquate Modellanpassung hindeuten kann.
#
# Auf Basis dieses Modells wurde eine Prognose bis Dezember 2025 erstellt. Die ARIMA-basierte Vorhersage zeigt ab Anfang 2025 einen weitgehend konstanten Verlauf der Median-Kaufpreise bei rund 845'000 CHF. Dies liegt daran, dass das Modell rein aus der Differenz vergangener Werte lernt und keine externen Einflussgrössen berücksichtigt.
#
# Die Breite des Konfidenzintervalls nimmt mit jeder Prognoseperiode stark zu, ein Hinweis auf zunehmende Unsicherheit im weiteren Verlauf der Immobilienpreise.
#
# Aus betriebswirtschaftlicher Sicht ist diese Prognose **nur bedingt hilfreich für Entscheidungsträger**, da:
# - keine Dynamik (Wachstum/Rückgang) antizipiert wird,
# - keine externen Einflussfaktoren wie Zins oder Inflation einbezogen sind,
# - die ökonomische Aussagekraft durch die hohe Prognoseunsicherheit begrenzt ist.
#
# **Fazit**: Das ARIMA(1,1,1)-Modell liefert eine statistisch signifikante und methodisch solide Grundlage. Für fundierte strategische Investitionsentscheidungen der Publica Pensionskasse eignet sich jedoch der Einsatz erweiterter Modelle, etwa **SARIMA** (mit Saisonalität) oder **SARIMAX** (mit exogenen Variablen), um externe Einflüsse und saisonale Effekte abzubilden.
#
# ### 5.4.2 Modelltraining SARIMA

# %%
# Wir teilen den DataFrame 'monthly_prices_forecast' in Trainings- und Testdaten (Split per Datum: train_end und train_start)

# Sicherstellen, dass datetime korrekt gesetzt ist
monthly_prices_forecast = monthly_prices_forecast.sort_index()

# Trainings- und Testzeitraum definieren
train_end = '2023-12-01'
test_start = '2024-01-01'

# Aufteilen
train_data = monthly_prices_forecast[:train_end]
test_data = monthly_prices_forecast[test_start:]

# Wir trainieren ein SARIMA-Modell mit saisonaler Komponente (s=12 für Monatsdaten)
# Hinweis: Die Wahl von s=12 basiert auf dem PACF-Plot in Kapitel 5.3, der einen signifikanten Ausschlag bei Lag 12–13 zeigt.
# Dies deutet auf eine mögliche saisonale Struktur im monatlichen Zeitintervall hin.

from statsmodels.tsa.statespace.sarimax import SARIMAX

# SARIMA(1,1,1)(1,1,1,12) als Startmodell (kann später optimiert werden)
sarima_model = SARIMAX(
    train_data['median_kaufpreis'],
    order=(1, 1, 1),
    seasonal_order=(1, 1, 1, 12),
    enforce_stationarity=False,
    enforce_invertibility=False
)

sarima_fit = sarima_model.fit(disp=False)
print(sarima_fit.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                   median_kaufpreis   No. Observations:                   72
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -508.175
# Date:                            Sat, 31 May 2025   AIC                           1026.351
# Time:                                    13:43:29   BIC                           1035.384
# Sample:                                01-01-2018   HQIC                          1029.718
#                                      - 12-01-2023
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0337      0.293     -0.115      0.908      -0.608       0.540
# ma.L1         -0.5480      0.196     -2.799      0.005      -0.932      -0.164
# ...

# %%
# Wir erstellen eine Prognose für die Länge des Testzeitraums (15 Monate)

forecast_steps = len(test_data)

sarima_pred = sarima_fit.get_forecast(steps=forecast_steps)
sarima_mean = sarima_pred.predicted_mean
sarima_ci = sarima_pred.conf_int()

# Wir visualisieren Trainingsdaten, echte Testwerte und Prognose inkl. Konfidenzintervall

plt.figure(figsize=(14, 6))

# Plot der historischen Trainingsdaten (bis Ende 2023)
plt.plot(train_data.index, train_data['median_kaufpreis'], label='Trainingsdaten', color='dodgerblue')

# Plot der tatsächlichen Kaufpreise im Testzeitraum (ab 01/2024)
plt.plot(test_data.index, test_data['median_kaufpreis'], label='Testdaten', color='darkviolet')

# Plot der durch SARIMA prognostizierten Werte für den Testzeitraum
plt.plot(test_data.index, sarima_mean, label='SARIMA Prognose', color='turquoise')

# Darstellung des 95%-Konfidenzintervalls der Prognose
plt.fill_between(
    test_data.index,
    sarima_ci.iloc[:, 0],
    sarima_ci.iloc[:, 1],
    color='turquoise',
    alpha=0.2,
    label='Konfidenzintervall (95%)'
)

plt.title("SARIMA-Prognose der Median-Kaufpreise (01/2024–03/2025)")
plt.xlabel("Zeit")
plt.ylabel("Kaufpreis [CHF]")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Interpretation und Optimierungsmöglichkeiten
#
# **Modellgüte und Signifikanz:**
# In der Modellübersicht (SARIMAX Results) ist nur ein Modellparameter (ma.L1) statistisch signifikant (p < 0.05), alle anderen p-Werte liegen darüber, d. h., ein Grossteil der geschätzten Parameter ist nicht signifikant. Das deutet darauf hin, dass die Modellstruktur insgesamt nicht optimal zur Datenstruktur passt.
#
# **Beispiel:**
# ar.L1 und ma.S.L12 sind sehr nahe bei null, was auf eine geringe Modellwirkung dieser Komponenten hindeutet. Die breiten Konfidenzintervalle, insbesondere bei ar.S.L12, deuten zudem auf unsichere Schätzungen und eine begrenzte Aussagekraft einzelner Modellparameter hin.
#
# **Konfidenzintervall:**
# Das Prognoseintervall ist relativ breit. Das ist bei SARIMA-Modellen nicht unüblich, zeigt jedoch, dass das Modell eine gewisse Unsicherheit hinsichtlich der Preisentwicklung aufweist. Je mehr Varianz im Trend und in der Saisonalität, desto grösser wird das Band.
#
# **Prognoseverlauf:**
# Die Prognosekurve (Türkis) liegt deutlich über den realen Testdaten. Das Modell überschätzt die Preisentwicklung, was auf suboptimale Saisonkomponenten, eine unpassende Differenzierung (d/D) oder auf fehlende exogene Variablen zurückgeführt werden kann.
#
# **Das bedeutet:**
# Publica erhält eine plausible Bandbreite (Range) möglicher Kaufpreise, jedoch keine robuste Punktprognose, was durch Anpassungen (siehe 5.4.3 Optimierung Modelltraining SARIMA) der Modellstruktur im nächsten Schritt verbessert werden sollte.
#
# ### 5.4.3 Optimierung Modelltraining SARIMA

# %%
# Wir definieren manuelle Kombinationen für SARIMA, um sie iterativ zu testen
# Parameterbereiche definieren
# Zur Begrenzung der Rechenzeit wurde der Parameterraum bewusst eng gewählt (0–1).
# So lassen sich die wichtigsten SARIMA-Strukturen testen, ohne die Rechenlast zu stark zu erhöhen.
p = d = q = range(0, 2)
P = D = Q = range(0, 2)
s = 12  # saisonal: 12 Monate

# Alle Kombinationen erzeugen
pdq = list(itertools.product(p, d, q))
seasonal_pdq = list(itertools.product(P, D, Q, [s]))

# DataFrame zur Ergebnisspeicherung
results = []

# Grid Search über alle Kombinationen
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            model = SARIMAX(train_data['median_kaufpreis'],
                            order=param,
                            seasonal_order=param_seasonal,
                            enforce_stationarity=False,
                            enforce_invertibility=False)
            result = model.fit(disp=False)
            results.append({
                'SARIMA': f'{param} x {param_seasonal}',
                'AIC': result.aic
            })
        except:
            continue

# Beste Kombination anzeigen
df_results = pd.DataFrame(results)
df_results = df_results.sort_values(by='AIC').reset_index(drop=True)
df_results.head(10)
# Out:
# /Users/nch/Library/Python/3.9/lib/python/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                       SARIMA          AIC
# 0  (0, 1, 1) x (1, 1, 1, 12)  1024.443638
# 1  (0, 1, 1) x (0, 1, 1, 12)  1025.129783
# 2  (1, 1, 1) x (1, 1, 1, 12)  1026.350571
# 3  (1, 1, 1) x (0, 1, 1, 12)  1027.072180
# 4  (1, 1, 1) x (1, 1, 0, 12)  1053.198400
# 5  (1, 1, 0) x (1, 1, 0, 12)  1055.587201
# 6  (1, 0, 1) x (1, 1, 1, 12)  1055.701743
# 7  (1, 1, 0) x (1, 1, 1, 12)  1057.431182
# 8  (1, 0, 1) x (0, 1, 1, 12)  1057.997795
# 9  (1, 1, 0) x (0, 1, 1, 12)  1059.559514

# %%
# Modell definieren und trainieren
model_opt = SARIMAX(
    train_data['median_kaufpreis'],
    order=(0, 1, 1),
    seasonal_order=(1, 1, 1, 12),
    enforce_stationarity=False,
    enforce_invertibility=False
)
results_opt = model_opt.fit(disp=False)

# Zusammenfassung anzeigen
print(results_opt.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                   median_kaufpreis   No. Observations:                   72
# Model:             SARIMAX(0, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -508.222
# Date:                            Sat, 31 May 2025   AIC                           1024.444
# Time:                                    13:43:31   BIC                           1031.670
# Sample:                                01-01-2018   HQIC                          1027.138
#                                      - 12-01-2023
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5590      0.151     -3.701      0.000      -0.855      -0.263
# ar.S.L12      -0.4391      0.265     -1.654      0.098      -0.959       0.081
# ...

# %%
# Forecast über die Länge des Testzeitraums
n_test = len(test_data)
sarima_forecast = sarima_fit.forecast(steps=n_test)

# Wir visualisieren den SARIMA-Forecast im Vergleich zu den echten Testdaten, inkl. Konfidenzintervall

# Prognose mit Konfidenzintervall
forecast_result = sarima_fit.get_forecast(steps=n_test)
forecast_mean = forecast_result.predicted_mean
conf_int = forecast_result.conf_int()

# Plot erstellen
plt.figure(figsize=(14, 6))
plt.plot(train_data.index, train_data['median_kaufpreis'], label='Trainingsdaten', color='dodgerblue')
plt.plot(test_data.index, test_data['median_kaufpreis'], label='Testdaten', color='darkviolet')
plt.plot(test_data.index, forecast_mean, label='SARIMA Prognose', color='turquoise')

# Konfidenzintervall als Schattierung
plt.fill_between(test_data.index,
                 conf_int.iloc[:, 0],
                 conf_int.iloc[:, 1],
                 color='turquoise',
                 alpha=0.3,
                 label='Konfidenzintervall (95%)')

# Plot konfigurieren
plt.title('Optimierte SARIMA-Prognose der Median-Kaufpreise (01/2024–03/2025)')
plt.xlabel('Zeit')
plt.ylabel('Kaufpreis [CHF]')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Wir berechnen MAE und RMSE für das SARIMA-Modell im Vergleich zu den echten Testdaten
# MAE berechnen
mae = mean_absolute_error(test_data['median_kaufpreis'], sarima_forecast)

# RMSE berechnen
rmse = np.sqrt(mean_squared_error(test_data['median_kaufpreis'], sarima_forecast))

# Ergebnisse ausgeben
print(f"MAE (Mean Absolute Error): {round(mae, 2)} CHF")
print(f"RMSE (Root Mean Squared Error): {round(rmse, 2)} CHF")
# Out:
# MAE (Mean Absolute Error): 28111.39 CHF
# RMSE (Root Mean Squared Error): 31967.13 CHF

# %% [markdown]
# ### Interpretation der Ergebnisse zu Kapitel 5.4.3
#
# **Fazit zur SARIMA-Modellierung der Kaufpreise (2018–2025)**
# Zur Prognose der monatlichen Median-Kaufpreise von Wohnimmobilien wurde zunächst ein SARIMA-Modell implementiert. Ziel war es, wiederkehrende Muster wie saisonale Effekte zu berücksichtigen und auf Basis der Zeitreihe belastbare Vorhersagen bis März 2025 zu generieren.
#
# In einem ersten Schritt wurde die Zeitreihe auf Stationarität geprüft. Nach erfolgter Differenzierung erfüllte die Reihe die stationären Anforderungen, was durch den Augmented-Dickey-Fuller-Test bestätigt wurde. Anschliessend wurden die Modellparameter manuell durch eine strukturierte Variantenanalyse optimiert. Dabei wurden zehn Kombinationen von SARIMA(p,d,q)×(P,D,Q,s)-Konfigurationen mit saisonaler Periode 12 evaluiert. Die Modellvariante **(0,1,1)×(1,1,1,12)** erzielte mit einem **AIC von 1024.44** den besten Wert in der Vergleichsreihe.
#
# Trotz dieser Optimierung zeigte das Modell Schwächen: Die Signifikanztests (p-Werte) der Parameter blieben überwiegend > 0.05, was auf eine eingeschränkte Aussagekraft der Komponenten hinweist. Auch der Prognoseverlauf überschätzte die tatsächliche Preisentwicklung im Testzeitraum (Jan. 2024 – März 2025) systematisch, was auf eine suboptimale Modellanpassung hindeutet. Die Prognosequalität gemessen an **MAE (28'111 CHF)** und **RMSE (31'967 CHF)** liegt im akzeptablen Bereich, bestätigt aber die eingeschränkte Genauigkeit.
#
# Insgesamt lässt sich festhalten, dass das SARIMA-Modell eine grundlegende Struktur der Zeitreihe abbildet, jedoch weder eine robuste Punktprognose noch eine realitätsnahe Abbildung der saisonalen Dynamik liefert. Die Ergebnisse deuten darauf hin, dass externe Einflussgrössen, etwa Zins- und Wohnimmobiliendaten, zur Verbesserung der Vorhersagequalität herangezogen werden sollten. Daher erfolgt im nächsten Schritt die Erweiterung des Modells zu einem **SARIMAX mit exogenen Variablen**.
#
# ### 5.4.4 Modelltraining SARIMAX mit exogenen Variablen
#
# Im letzten Schritt der Zeitreihenanalyse erweitern wir das SARIMA-Modell um externe Einflussfaktoren in Form exogener Variablen. Dazu verwenden wir das **SARIMAX-Modell**, das sowohl autoregressive als auch externe (makroökonomische) Einflussgrössen berücksichtigen kann. Ziel ist es zu prüfen, ob sich die Prognosequalität verbessert, wenn zusätzliche erklärende Grössen wie **Hypothekarzinsen** oder der **Wohnimmobilienpreisindex (IMPI)** in das Modell eingebunden werden.
#
#
#
# **Datenbasis und Einschränkungen:**
#
# Für die Modellierung mit SARIMAX stehen folgende externe Variablen zur Verfügung:
#
# - Der **Zinssatz** (df_zins) liegt auf monatlicher Basis vor und ist bis **Ende 2024** verfügbar.
# - Der **Wohnimmobilienpreisindex (IMPI)** liegt quartalsweise von **2017Q1 bis 2024Q4** vor (df_impi bzw. df_wohn).
#
# Andere verfügbare externe Reihen (z. B. Inflation) wurden aufgrund der zeitlichen Granularität (nur jährlich) für diese Analyse nicht berücksichtigt.
#
#
#
# **Modellvarianten:**
#
# Zur Evaluierung der SARIMAX-Ansätze werden zwei Modellvarianten getestet:
#
# 1. **SARIMAX mit monatlichen Hypothekarzinsen** (Kapitel 5.4.4.1)
# 2. **SARIMAX mit dem Wohnimmobilienpreisindex (IMPI) auf Quartalsbasis** (Kapitel 5.4.4.2)
#
# Beide Varianten werden jeweils separat trainiert und validiert. Die Zielgrösse bleibt der monatlich bzw. quartalsweise aggregierte **Median-Kaufpreis von Wohnimmobilien** aus dem DataHive-Datensatz.
#
#
#
# **Zielsetzung:**
#
# Das Ziel dieser Erweiterung ist es, eine robuste und erklärbare Prognose der Immobilienpreise zu ermöglichen, indem neben der Autokorrelation auch externe Marktdynamiken berücksichtigt werden. Die Ergebnisse werden anhand der Prognosegüte (MAE, RMSE) und der visuellen Übereinstimmung mit den realen Testdaten beurteilt.
#
#
#
# **Vorgehen:**
#
# Im folgenden Schritt wird der Zinsdatensatz so aufbereitet, dass er für das SARIMAX-Modell als exogene Variable verwendbar ist. Der Merge erfolgt auf Basis von **Jahr und Monat**, und das Modell wird später auf den Zeitraum von **01.01.2018 bis 31.12.2024** trainiert.

# %%
# Vorbereitung: Wir prüfen den verfügbaren Zeitraum des df_zins DataFrames anhand der Spalten 'jahr' und 'monat'

print("Frühester Eintrag:", dataService.dfHypo[['jahr', 'monat']].iloc[0].to_dict())
print("Spätester Eintrag:", dataService.dfHypo[['jahr', 'monat']].iloc[-1].to_dict())
# Out:
# Frühester Eintrag: {'jahr': 2005, 'monat': 5}
# Spätester Eintrag: {'jahr': 2024, 'monat': 12}

# %%
# Vorbereitung: Wir prüfen den verfügbaren Zeitraum des monthly_prices_forecast DataFrames anhand der Spalten 'year' und 'month'
print("Erster Eintrag:", monthly_prices_forecast[['year', 'month']].iloc[0].to_dict())
print("Letzter Eintrag:", monthly_prices_forecast[['year', 'month']].iloc[-1].to_dict())
# Out:
# Erster Eintrag: {'year': 2018, 'month': 1}
# Letzter Eintrag: {'year': 2025, 'month': 3}

# %%
# Vorbereitung: Wir prüfen den verfügbaren Zeitraum des Forecast-DataFrames auf Monatsbasis

print("Forecast-Zeitraum von", monthly_prices_forecast.index.min().date(), 
      "bis", monthly_prices_forecast.index.max().date())
# Out:
# Forecast-Zeitraum von 2018-01-01 bis 2025-03-01

# %% [markdown]
# #### 5.4.4.1 Modelltraining SARIMAX mit Hypothekarzinsen als exogene Variable

# %%
# Wir bereiten den Datensatz für das SARIMAX-Modell vor, indem wir die monatlichen Kaufpreise
# mit den Zinsdaten (df_zins) für den Zeitraum 2018–2024 zusammenführen.

# Schritt 1: Datum in dfDataHiveCleaned als datetime interpretieren
dhService.dfDataHiveCleaned['activated'] = pd.to_datetime(dhService.dfDataHiveCleaned['activated'], errors='coerce')

# Schritt 2: Jahr und Monat aus Datum extrahieren
dhService.dfDataHiveCleaned['jahr'] = dhService.dfDataHiveCleaned['activated'].dt.year
dhService.dfDataHiveCleaned['monat'] = dhService.dfDataHiveCleaned['activated'].dt.month

# Schritt 3: Median-Kaufpreis pro Monat berechnen
monthly_prices = dhService.dfDataHiveCleaned.groupby(['jahr', 'monat'])['purchase_price'].median().reset_index()
monthly_prices.rename(columns={'purchase_price': 'median_kaufpreis'}, inplace=True)

# Schritt 4: Zinsdaten (df_zins) auf Zeitraum 2018–2024 filtern
df_zins_filtered = dataService.dfHypo[(dataService.dfHypo['jahr'] >= 2018) & (dataService.dfHypo['jahr'] <= 2024)].copy()

# Schritt 5: Kaufpreisdaten auf gleichen Zeitraum filtern
monthly_prices_filtered = monthly_prices[(monthly_prices['jahr'] >= 2018) & (monthly_prices['jahr'] <= 2024)].copy()

# Schritt 6: Kaufpreise und Zinsen über Jahr und Monat verbinden
df_sarimax = pd.merge(
    monthly_prices_filtered,
    df_zins_filtered,
    left_on=['jahr', 'monat'],
    right_on=['jahr', 'monat'],
    how='inner'  # nur gemeinsame Monate behalten
)

# Schritt 7: Zeitstempel-Index erstellen für Zeitreihenmodellierung
df_sarimax['date'] = pd.to_datetime(df_sarimax['jahr'].astype(str) + '-' + df_sarimax['monat'].astype(str))
df_sarimax.set_index('date', inplace=True)

# Wir teilen den df_sarimax in Trainings- und Testdaten für das SARIMAX-Modell
# Zeitraum:
# - Training: Jan 2018 – Dez 2023
# - Test: Jan 2024 – Dez 2024

# Split durchführen
train_sarimax = df_sarimax[(df_sarimax.index >= '2018-01-01') & (df_sarimax.index <= '2023-12-01')].copy()
test_sarimax = df_sarimax[(df_sarimax.index >= '2024-01-01') & (df_sarimax.index <= '2024-12-01')].copy()

# Kontrolle der Zeiträume
print("Trainingszeitraum:", train_sarimax.index.min().date(), "bis", train_sarimax.index.max().date())
print("Testzeitraum:", test_sarimax.index.min().date(), "bis", test_sarimax.index.max().date())

# Wir definieren ein SARIMAX-Modell mit der exogenen Variable "festhypo_mittelwert"
# und trainieren es auf den Trainingsdaten von 2018–2023.

# SARIMAX-Modell mit saisonaler Komponente (s=12 für Monatssaisonalität)
sarimax_model = SARIMAX(
    train_sarimax['median_kaufpreis'],         # Zielvariable
    exog=train_sarimax[['festhypo_mittelwert']],  # Exogene Variable
    order=(0, 1, 1),                             # (p,d,q) – später optimierbar
    seasonal_order=(1, 1, 1, 12),                # (P,D,Q,s)
    enforce_stationarity=False,
    enforce_invertibility=False
)

# Modell fitten
sarimax_fit = sarimax_model.fit(disp=False)

# Modellzusammenfassung anzeigen
print(sarimax_fit.summary())
# Out:
# Trainingszeitraum: 2018-01-01 bis 2023-12-01
# Testzeitraum: 2024-01-01 bis 2024-12-01
#                                      SARIMAX Results
# ...
# Dep. Variable:                   median_kaufpreis   No. Observations:                   72
# Model:             SARIMAX(0, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -508.592
# Date:                            Sat, 31 May 2025   AIC                           1027.183
# Time:                                    13:43:31   BIC                           1036.216
# Sample:                                01-01-2018   HQIC                          1030.551
#                                      - 12-01-2023
# Covariance Type:                              opg
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# festhypo_mittelwert -1.727e+04   2.81e+04     -0.614      0.540   -7.24e+04    3.79e+04
# ...

# %%
# Wir prognostizieren die Median-Kaufpreise mit dem trainierten SARIMAX-Modell für 2024
# und vergleichen die Vorhersage mit den realen Testdaten (test_sarimax)

# Länge der Testperiode (12 Monate Jan–Dez 2024)
n_test = len(test_sarimax)

# Prognose erzeugen – wichtig: exogene Werte aus dem Testset mitgeben!
sarimax_forecast = sarimax_fit.forecast(
    steps=n_test,
    exog=test_sarimax[['festhypo_mittelwert']]
)

# Konfidenzintervalle abrufen
sarimax_pred = sarimax_fit.get_forecast(
    steps=n_test,
    exog=test_sarimax[['festhypo_mittelwert']]
)
conf_int = sarimax_pred.conf_int()

# Visualisierung der Vorhersage

plt.figure(figsize=(14, 6))
plt.plot(train_sarimax.index, train_sarimax['median_kaufpreis'], label='Trainingsdaten', color='dodgerblue')
plt.plot(test_sarimax.index, test_sarimax['median_kaufpreis'], label='Testdaten', color='darkviolet')
plt.plot(test_sarimax.index, sarimax_forecast, label='SARIMAX Prognose', color='turquoise')

# Konfidenzintervall einzeichnen
plt.fill_between(test_sarimax.index,
                 conf_int.iloc[:, 0],
                 conf_int.iloc[:, 1],
                 color='turquoise', alpha=0.3, label='Konfidenzintervall (95%)')

plt.title("SARIMAX-Prognose mit Hypothekarzinsen als exogene Variable")
plt.xlabel("Zeit [Monatsbasis]")
plt.ylabel("Kaufpreis [CHF]")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Wir berechnen MAE und RMSE für das SARIMAX-Modell im Vergleich zu den echten Testdaten
# MAE berechnen
mae = mean_absolute_error(test_sarimax['median_kaufpreis'], sarimax_forecast)

# RMSE berechnen
rmse = np.sqrt(mean_squared_error(test_sarimax['median_kaufpreis'], sarimax_forecast))

# Ergebnisse ausgeben
print(f"MAE (Mean Absolute Error): {round(mae, 2)} CHF")
print(f"RMSE (Root Mean Squared Error): {round(rmse, 2)} CHF")
# Out:
# MAE (Mean Absolute Error): 43882.45 CHF
# RMSE (Root Mean Squared Error): 49273.06 CHF

# %% [markdown]
# ### Interpretation der Ergebnisse zu 5.4.4.1
#
# **Fazit zur SARIMAX-Prognose mit Hypothekarzinsen als exogene Variable**
#
# Das SARIMAX-Modell wurde mit den monatlichen Hypothekarzinsen als exogene Variable trainiert. Die Hoffnung war, dadurch die Prognosequalität zu verbessern. Die Ergebnisse zeigen jedoch:
#
# - **Keine Verbesserung der Prognosegüte:**
#   Die Fehlerwerte (MAE, RMSE) liegen deutlich über jenen des SARIMA-Modells
#   _(SARIMA: MAE ≈ 28'111 CHF vs. SARIMAX: MAE ≈ 43'882 CHF)_.
#
# - **Geringe Signifikanz der exogenen Variable:**
#   Die Koeffizienten im Modelloutput sind nicht signifikant _(p-Wert > 0.05)_, was auf eine schwache erklärende Wirkung der Zinsdaten hindeutet.
#
# - **Modellinstabilität:**
#   Die Warnung zur Kovarianzmatrix deutet darauf hin, dass das Modell möglicherweise überparametrisiert oder instabil ist.
#
# - **Visuelle Abweichungen:**
#   Auch in der Prognosegrafik liegt die SARIMAX-Prognose systematisch über den tatsächlichen Kaufpreisen.
#
# **Schlussfolgerung:**
# Trotz der theoretischen Erwartung, dass Zinsen den Immobilienpreis beeinflussen, liefert das SARIMAX-Modell mit den aktuell verfügbaren Daten _(2018–2024)_ keine bessere Prognosequalität als ein einfaches SARIMA-Modell. Weitere Optimierung _(z. B. Feature Engineering, Modellselektion oder andere exogene Variablen)_ wären nötig, um echte Mehrwerte zu erzielen.
#
# #### 5.4.4.2 Modelltraining SARIMAX mit Wohnimmobilienpreisindex (IMPI) auf Quartalsbasis
#
# In diesem Abschnitt erstellen wir ein SARIMAX-Modell, das auf Quartalsdaten basiert. Ziel ist es, die Entwicklung der Median-Kaufpreise für Wohnimmobilien zu prognostizieren, unter Berücksichtigung externer Einflüsse durch den Wohnimmobilienpreisindex (IMPI) als exogene Variable.
#
# Die Motivation für dieses Modell ergibt sich aus der Tatsache, dass:
#
# - Der Wohnimmobilienpreisindex (df_wohn bzw. df_impi) quartalsweise verfügbar ist (2017Q1–2024Q4).
# - Die bereinigten Kaufpreise aus dem DataHive-Datensatz (dfDataHiveCleaned) ebenfalls auf Quartalsbasis aggregiert wurden (ab 2018Q1).
# - Durch den Einsatz eines SARIMAX-Modells können sowohl saisonale Muster als auch externe Einflussfaktoren (z. B. Marktpreisindizes) modelliert werden.
#
# Vorgehensweise:
# 1. Aggregation der Median-Kaufpreise pro Quartal ab 2018Q1.
# 2. Transformation und Harmonisierung der Quartalsdaten aus df_wohn (z. B. «Q1» → 1).
# 3. Zusammenführung beider Datensätze (df_merge_impi) auf Basis von Jahr und Quartal.
# 4. Erstellung eines Zeitstempelindex zur Verwendung in Zeitreihenmodellen.
# 5. Anwendung eines SARIMAX-Modells mit dem IMPI als exogener Einflussfaktor.
# 6. Evaluation der Prognosegüte (MAE, RMSE) im Vergleich zu realen Quartalsdaten.
#
# Ziel:
# Eine robustere, erklärbare Prognose der Kaufpreisentwicklung auf Quartalsbasis, die zusätzlich zur Autokorrelation auch externe Marktbedingungen berücksichtigt.

# %%
# Quartal in Startmonat übersetzen (Q1 = Jan = 1, Q2 = Apr = 4, etc.)
dhService.df_merge_impi['monat'] = (dhService.df_merge_impi['quartal'] - 1) * 3 + 1

# Datum aus Jahr und Monat erzeugen
dhService.df_merge_impi['date'] = pd.to_datetime(dict(year=dhService.df_merge_impi['jahr'], month=dhService.df_merge_impi['monat'], day=1))

# Index setzen
dhService.df_merge_impi.set_index('date', inplace=True)

# Wir teilen den DataFrame df_merge_impi in Trainings- und Testdaten für das SARIMAX-Modell (mit IMPI)
# Zeitraum:
# - Training: 2018-01-01 bis 2023-12-31 (entspricht 2018Q1–2023Q4)
# - Test:     2024-01-01 bis 2024-10-01 (entspricht 2024Q1–2024Q4)

# Split durchführen
train_impi = dhService.df_merge_impi.loc['2018-01-01':'2023-12-31'].copy()
test_impi = dhService.df_merge_impi.loc['2024-01-01':'2024-10-01'].copy()

# Kontrolle
print("Trainingszeitraum:", train_impi.index.min().date(), "bis", train_impi.index.max().date())
print("Testzeitraum:", test_impi.index.min().date(), "bis", test_impi.index.max().date())
# Out:
# Trainingszeitraum: 2018-01-01 bis 2023-10-01
# Testzeitraum: 2024-01-01 bis 2024-10-01

# %%
# Wir trainieren das SARIMAX-Modell mit dem Wohnimmobilienpreisindex (IMPI) als exogene Variable
# SARIMAX(p=1, d=1, q=1) mit saisonalen Parametern (P=1, D=1, Q=1, s=4) für Quartale

# Exogene Variable definieren
exog_train = train_impi[['total']]

# SARIMAX-Modell definieren und fitten
sarimax_model_impi = SARIMAX(
    train_impi['median_kaufpreis'],
    order=(1, 1, 1),
    seasonal_order=(1, 1, 1, 4),
    exog=exog_train,
    enforce_stationarity=False,
    enforce_invertibility=False
)

# Modell fitten
sarimax_fit_impi = sarimax_model_impi.fit(disp=False)

# Zusammenfassung anzeigen
print(sarimax_fit_impi.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                  median_kaufpreis   No. Observations:                   24
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 4)   Log Likelihood                -143.914
# Date:                           Sat, 31 May 2025   AIC                            299.827
# Time:                                   13:43:31   BIC                            303.217
# Sample:                               01-01-2018   HQIC                           299.131
#                                     - 10-01-2023
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# total       3908.0035   5345.212      0.731      0.465   -6568.419    1.44e+04
# ar.L1          0.3103      1.384      0.224      0.823      -2.402       3.022
# ...

# %%
# SARIMAX-Modell mit IMPI (Quartalsdaten) trainieren

# Modell definieren
sarimax_model_imp = SARIMAX(
    train_impi['median_kaufpreis'],
    exog=train_impi[['total']],
    order=(1, 1, 1),
    seasonal_order=(1, 1, 1, 4),
    enforce_stationarity=False,
    enforce_invertibility=False
)

# Modell fitten
sarimax_fit_imp = sarimax_model_imp.fit(disp=False)
# Out:
# /Users/nch/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /Users/nch/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)

# %%
# Wir prognostizieren die Median-Kaufpreise für 2024Q1–2024Q4 mit dem trainierten SARIMAX-Modell (mit IMPI)
# und vergleichen sie mit den tatsächlichen Testdaten
# Anzahl Testperioden (z.B. 4 Quartale)
n_test = len(test_impi)

# Exogene Variable für die Testperiode extrahieren
exog_forecast = test_impi[['total']]

# Prognose generieren
sarimax_forecast = sarimax_fit_imp.predict(
    start=len(train_impi),
    end=len(train_impi) + n_test - 1,
    exog=exog_forecast
)

# Konfidenzintervall generieren (optional für Visualisierung)
pred_result = sarimax_fit_imp.get_prediction(
    start=len(train_impi),
    end=len(train_impi) + n_test - 1,
    exog=exog_forecast
)
conf_int = pred_result.conf_int()

# Visualisierung der Prognose
plt.figure(figsize=(12, 6))
plt.plot(train_impi.index, train_impi['median_kaufpreis'], label='Trainingsdaten', color='dodgerblue')
plt.plot(test_impi.index, test_impi['median_kaufpreis'], label='Testdaten', color='darkviolet')
plt.plot(test_impi.index, sarimax_forecast, label='SARIMAX Prognose (mit IMPI)', color='turquoise')
plt.fill_between(test_impi.index, conf_int.iloc[:, 0], conf_int.iloc[:, 1], color='turquoise', alpha=0.3, label='Konfidenzintervall (95%)')

plt.title("SARIMAX-Prognose mit IMPI als exogene Variable")
plt.xlabel("Zeit [Quartalsbasis]")
plt.ylabel("Kaufpreis [CHF]")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# MAE berechnen
mae_impi = mean_absolute_error(test_impi['median_kaufpreis'], sarimax_forecast)

# RMSE berechnen
rmse_impi = np.sqrt(mean_squared_error(test_impi['median_kaufpreis'], sarimax_forecast))

# Ergebnisse ausgeben
print(f"MAE (Mean Absolute Error): {round(mae_impi, 2)} CHF")
print(f"RMSE (Root Mean Squared Error): {round(rmse_impi, 2)} CHF")
# Out:
# MAE (Mean Absolute Error): 20091.29 CHF
# RMSE (Root Mean Squared Error): 21785.53 CHF

# %% [markdown]
# #### 5.4.4.3 Erkenntnisse aus dem Vergleich der SARIMAX-Modelle (IMPI vs. Hypothekarzins)
#
# Ziel des Vergleichs:
#
# Ziel des Modellvergleichs war es, die Prognosequalität zweier SARIMAX-Modelle zu bewerten, welche die Entwicklung der **Median-Kaufpreise für Wohnimmobilien** modellieren. Dabei wurde jeweils eine unterschiedliche **exogene Variable** berücksichtigt:
# - **Modell 1:** SARIMAX mit Hypothekarzinsen (Zinsdaten)
# - **Modell 2:** SARIMAX mit Wohnimmobilienpreisindex (IMPI)
#
#
# Bewertungskriterien:
#
# Die Modelle wurden hinsichtlich folgender Aspekte verglichen:
# - **Prognosegenauigkeit:** MAE (Mean Absolute Error) und RMSE (Root Mean Squared Error)
# - **Visualisierung der Vorhersagequalität** im Vergleich zu realen Testdaten (2024Q1–Q4)
# - **Erklärbarkeit durch externe Einflussfaktoren**
#
#
# Modell mit Hypothekarzinsen (Zinsdaten):
#
# - **MAE:** ca. 43'882 CHF
# - **RMSE:** ca. 49'273 CHF
# - **Tendenz:** Die Prognose lag im Durchschnitt merklich über den tatsächlichen Werten im Testzeitraum.
# - **Unsicherheitsbereich:** Breites Konfidenzintervall; weniger stabiles Modellverhalten.
#
#
# Modell mit Wohnimmobilienpreisindex (IMPI):
#
# - **MAE:** ca. 20'091 CHF
# - **RMSE:** ca. 21'785 CHF
# - **Tendenz:** Prognoseverlauf näher an den realen Kaufpreisen, besonders in 2024Q2–Q4.
# - **Unsicherheitsbereich:** Deutlich engeres Konfidenzintervall, robustere Schätzung.
# - **Hinweis:** Trotz der deutlich besseren Prognosewerte des SARIMAX-Modells mit IMPI weisen die Modellparameter keine statistische Signifikanz auf (p > 0.05). Dies deutet auf strukturelle Unsicherheiten und eine begrenzte Erklärungskraft einzelner Regressionskomponenten hin.
#
#
# Interpretation und Fazit:
#
# - Das **SARIMAX-Modell mit dem Wohnimmobilienpreisindex (IMPI)** liefert eine **deutlich bessere Prognosegüte** als das Modell mit Zinsdaten. Dies zeigt sich klar in den niedrigeren MAE- und RMSE-Werten.
# - Der **IMPI als exogene Variable** ist besser geeignet, Marktbewegungen auf Quartalsbasis abzubilden, da er **direkter mit der Immobilienpreisentwicklung** korreliert als der kurzfristigere Hypothekarzinssatz.
# - Das Modell mit Zinsdaten zeigt **grössere Unsicherheit und Übersteuerung**, insbesondere bei saisonalen Effekten.
# - Die **Visualisierung** der Prognose unterstreicht die höhere **Stabilität und Erklärungskraft** des IMPI-Modells.
#
#
# Schlussfolgerung:
#
# Für die Prognose der Median-Kaufpreise im Schweizer Wohnimmobilienmarkt bietet der **Wohnimmobilienpreisindex (IMPI)** einen **relevanteren und robusteren externen Einflussfaktor** als Hypothekarzinsen. Für künftige Modellierungen auf Quartalsbasis empfiehlt sich der IMPI als robuste und erklärungskräftige exogene Variable.
#
#
# #### Erweiterter Forecast bis 2028 – Einordnung und Entscheidung
#
# In einem abschliessenden Schritt wurde untersucht, ob sich die bereits trainierten SARIMA- und SARIMAX-Modelle für eine langfristige Prognose bis Ende 2028 eignen. Ziel war es, über eine Erweiterung des Prognosehorizonts (um bis zu 20 Quartale bzw. 60 Monate) strategische Planungssicherheit für Investitionsentscheidungen im Schweizer Immobilienmarkt zu gewinnen.
#
# Technisch wurde dies realisiert durch:
#
# - eine methodisch saubere Extrapolation der exogenen Variablen (Zinsen & IMPI),
#
# - eine Fortführung des Forecasts über die bestehenden Modelle bis Q4 2028,
#
# - sowie eine vergleichende Visualisierung der Prognoseverläufe.
#
# Die Ergebnisse bestätigen, dass das SARIMAX-Modell mit IMPI auch im erweiterten Zeithorizont stabilere und nachvollziehbarere Vorhersagen liefert als das SARIMAX-Modell mit Hypothekarzinsen. Die Unsicherheitsbänder bleiben vergleichsweise eng, und die saisonalen Muster werden plausibel fortgeführt. Der SARIMA-Ansatz ohne Exogene hingegen zeigt stärkere Ausschläge und reagiert empfindlicher auf Störungen, insbesondere bei längerfristigen Trends.
#
# Fazit:
#
# Da die zentralen Erkenntnisse dieser Langfristanalyse die bereits gewonnenen Resultate aus Kapitel 5.4.4 bestätigen, wird auf eine detaillierte Darstellung des erweiterten Forecasts in einem separaten Kapitel verzichtet. Die entsprechenden Visualisierungen und Modellvergleiche wurden intern im Jupyter-Notebook (Datenanalyse_Kapitel_4_5.ipynb) erarbeitet und dokumentiert. Für die Entscheidungsfindung von Publica ergibt sich daraus eine klare Empfehlung zugunsten des robusteren SARIMAX-Modells mit IMPI.

# %% [markdown]
# ## 6. Fazit & Ausblick
#
# *(CPA Steps 4 & 5: Presenting information + Making data-driven decisions)*
#
# Die Analysen in dieser datenbasierten Case Study bestätigen, dass zwischen 2013 und 2025, die Zinsentwicklung und die Inflationsrate einen messbaren Einfluss auf den Schweizer Immobilienmarkt hatten. Die Phase zwischen 2013 und 2021, war durch tiefe Zinsen und kontinuierlich steigende Preise geprägt. Die im Jahre 2022 von der SNB veranlassten geldpolitischen Anpassungen führten zu einer spürbaren Veränderung in Nachfrage, Leistbarkeit und Preisentwicklung bei Immobilien. Insbesondere gut angebundene, periphere Regionen konnten durch eine moderate Preisentwicklung und der stabilen Nachfrage ihre Attraktivität weiter steigern.
#
# #### Empfehlungen an die Geschäftsleitung der Publica
#
# Basierend auf diesen Erkenntnissen und den Analysen, möchte die Projektgruppe der Immobilienabteilung, der Geschäftsleitung der Publica bezüglich zukünftiger Investitionen im Immobiliensektor die folgenden Empfehlungen unterbreiten.
#
# **Empfehlung 1:** Ein besonderer Investitionsfokus sollte auf 3.5-4.5 Zimmerwohnungen gelegt werden. Erfahrungsgemäss deckt diese Segmentgrösse den Grossteil der Nachfragen ab und bietet der Publica ein stabiles sowie risikoarmes Renditepotenzial.
#
# **Empfehlung 2:** Bei eine Projektfinanzierung eines Renditeobjekts sollten hauptsächlich langfristige Festhypotheken (7-10 Jahre) in Betracht gezogen werden. Mit Langzeithypotheken kann sich die Publica gegen zukünftige Zinsanstiege absichern und gegenüber den Versicherten regelmässige Ausschüttungen garantieren.
#
# **Empfehlung 3:** Bezüglich der Objektselektion, sollten ländliche Gemeinden mit guter Erschliessung in Betracht gezogen werden. Gut erschlossene Regionen  bieten ein enormes Potenzial.  Diese Regionen zeichnen sich durch eine stabile Nachfrage und ein moderates Preiswachstum aus.
#
# **Empfehlung 4:** Die Immobilienabteilung empfiehlt die bisher getätigten Investitionen im Schweizer Immobiliensektor zu überprüfen. Besonders in städtischen Gemeinden und in der Agglomeration können Miet – und Kaufpreise rasant und stark ansteigen. In Regionen, welche überdurchschnittlich schnell wachsen, können Kaufpreise ein nachhaltiges Renditeniveau rasch übersteigen.
#
# Diese auf einem datengestützten Ansatz basierenden Empfehlungen sollen Publica bei zukünftigen Investitionen in den Schweizer Immobiliensektor unterstützen. Sie unterstützen das strategische Ziel von Publica, für die Kunden das bestmögliche Rendite-Risiko-Verhältnis zu erzielen und so der Verantwortung als Versicherer gegenüber den Versicherten nachhaltig gerecht zu werden.
#
#
# #### Grenzen der Datenanalyse
#
# Die Analyse basiert zum grössten Teil auf aggregierten Zeitreihen und strukturierten Daten aus Immobilieninseraten (DataHive). Dadurch ergeben sich gewisse Einschränkungen in der Datenanalyse:
#
# 1.	Mikroökonomische Daten wie zum Beispiel die individuellen Finanzierungsbedingungen von Personen oder regionale Bauvorschriften sind nicht abgedeckt.
#
# 2.	Es ist nicht zwingend das die Daten in einen Immobilieninserat auch die tatsächlich abgewickelte Transaktion widerspiegelt. Dementsprechend sollten die Analysen mit den effektiven Transaktionsdaten wie zum Beispiel Grundbuchstatistiken ergänzt werden.
#
# Letztendlich muss berücksichtig werden, dass die analysierte Zeitperiode (2013-2025) von starken externen Schocks (COVID-19-Pandemie, geopolitische Spannungen) geprägt war.  Solche Ereignisse haben bedeutende und schwer vorhersehbare Auswirkungen auf das Immobilienmarktverhalten. Auf der Basis von historischen Zeitreihen, sind kurzfristige Entwicklungen wie geldpolitische Kurswechsel oder regulatorische Neuerungen, schwer zu prognostizieren.
#
# #### Weiterführende Ideen und zukünftige Projekte
#
# Damit die Immobilienabteilung von Publica in Zukunft laufen datenbasierte Entscheidungen treffen kann, wird in einem nächsten Schritt mit der Implementierung von einem interaktiven Dashboard gestartet.
#
# Damit datenbasierte Entscheidungen langfristig effizient getroffen werden können, sollte Publica mit der Entwicklung eines internen Visual Analytics Dashboard beginnen. Zentrale Marktdaten könnten so einheitlich und in strukturierter Form zusammengeführt werden. Für die Umsetzung eignen sich Power BI oder eine eigene in-house Entwicklung in Python. Mit einem solchen Tool könnte die Immobilienabteilung von Publica die wichtigsten ökonomischen Faktoren im Immobiliensektor effizient analysieren und Investitionspotenziale frühzeitig erkennen. Risikoindikatoren wären gut überwacht und man könnte unterschiedliche Kaufs- und Verkauf Szenarien simulieren.
#
# Die Entwicklung eines solchen Dashboards wäre für Publica ein wichtiger Meilenstein auf dem Weg zu einer konsistenten und agilen Steuerung der Immobilienstrategie.

# %% [markdown]
# ## 7. Anhang
#
# ### 7.1 Literaturverzeichnis
#
# Marr, B. (2020). A FIVE-STEP APPROACH TO DATA-DRIVEN DECISION-MAKING.
#
# UBS Asset Management. (2025). Top 10 questions Real estate markets in 2025.
# https://www.ubs.com/ch/en/assetmanagement/insights/asset-class-perspectives/real-estate/articles/top-10-questions-real-estate-markets-in-2025.html
#
# UBS (Schweiz) AG. (2024). UBS Real Estate Focus 2024.
# https://www.ubs.com/global/de/wealthmanagement/insights/2025/real-estate-focus.html
#
# UBS (Schweiz) AG. (2025). UBS Real Estate Focus 2025.
# https://www.ubs.com/global/de/wealthmanagement/insights/2025/real-estate-focus.html
#
# Datenportal der Schweizerischen Nationalbank. (2025). Datenportal der Schweizerischen Nationalbank.
# https://data.snb.ch/de/topics/ziredev/cube/zikredlauf
#
# Landesindex der Konsumentenpreise. (2025, Mai 10).
# https://www.bfs.admin.ch/content/bfs/de/home/statistiken/preise/erhebungen/lik.html
#
# Steckbrief: Schweizerischer Wohnimmobilienpreisindex. (2024, Dezember 16). Steckbrief : Schweizerischer Wohnimmobilienpreisindex. https://www.bfs.admin.ch/asset/de/33707302
#
# ### 7.2 NDA-Hinweis DataHive
#
# Die in dieser Fallstudie verwendeten Daten der Firma DataHive unterliegen einer Vertraulichkeitsvereinbarung (NDA – Non-Disclosure Agreement). Die Inhalte der Arbeit, insbesondere sämtliche Darstellungen, Analysen und Interpretationen basierend auf diesen Daten, dürfen nicht veröffentlicht, vervielfältigt oder an Dritte weitergegeben werden. Eine Weiterleitung oder Nutzung ausserhalb des vorgesehenen Projektkontexts ist ausdrücklich untersagt.
